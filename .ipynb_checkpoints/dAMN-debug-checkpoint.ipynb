# %% [markdown]
# # dAMN with M28 dataset

# %% [markdown]
# ## Train

# %%
import tensorflow as tf
print("TF version:", tf.__version__)
print("Keras version:", tf.keras.__version__)
import sys
print(sys.executable)
# Out:
# TF version: 2.16.2
# Keras version: 3.9.2
# /Users/jean-loup-faulon/miniforge3/envs/M4/bin/python

# %%
import json

config_path = "./model_july31/M28_OD_20_forecast_0.config.json"  # July version

with open(config_path, "r") as f:
    cfg = json.load(f)

print("loss_weight:", cfg["loss_weight"])
print("loss_decay:", cfg["loss_decay"])
# Out:
# loss_weight: [0.001, 1, 1, 1]
# loss_decay: [0, 0.5, 0.5, 1]

# %%
# train with july arrays

# This cell is slow you should run train.py code

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import tensorflow as tf
import utils
import data
import model
import plot
print('Physical GPUs:', tf.config.list_physical_devices('GPU'))

train_test_split = 'forecast' # 'forecast' or 'medium'
folder = './'
file_name = 'M28_OD_20'
media_file = folder+'data/'+'M28_media.csv'                 
od_file = folder+'data/'+file_name+'.csv'               
cobra_model_file = folder+'data/'+'iML1515_duplicated.xml'
biomass_rxn_id = 'BIOMASS_Ec_iML1515_core_75p37M'

# Hyperparameters (same as July)
seed = 10
np.random.seed(seed=seed)
hidden_layers_lag = [50]
hidden_layers_flux = [500]
num_epochs = 1000
x_fold = 3    
batch_size = 10
patience = 100
N_iter = 3
run_name = f'{file_name}_{train_test_split}'

# -------------------------------------------------------------------
# 1) Build the model using the CURRENT code, but ignore the arrays it returns
#    (we'll overwrite them with the July arrays below).
# -------------------------------------------------------------------
mdl, _, _, _, _, _ = model.create_model_train_val(
    media_file, od_file,
    cobra_model_file,
    biomass_rxn_id,
    x_fold=x_fold, 
    hidden_layers_lag=hidden_layers_lag, 
    hidden_layers_flux=hidden_layers_flux, 
    dropout_rate=0.2,
    loss_weight=[0.001, 1, 1, 1], # july
    loss_decay=[0, 0.5, 0.5, 1],
    verbose=True,
    train_test_split=train_test_split
)

# -------------------------------------------------------------------
# 2) Load the EXACT July arrays (old prefix: "M28o_...") and reconstruct
#    July's train_array and train_dev from them.
# -------------------------------------------------------------------
old_prefix = f'{folder}model_july31/{file_name}_{train_test_split}'
# If your July files are named differently, adjust this pattern accordingly.

old_val_array_path = old_prefix + '_val_array.txt'
old_val_dev_path   = old_prefix + '_val_dev.txt'
old_val_ids_path   = old_prefix + '_val_ids.txt'

print("\nLoading July arrays from:")
print("  ", old_val_array_path)
print("  ", old_val_dev_path)
print("  ", old_val_ids_path)

val_array = np.loadtxt(old_val_array_path, dtype=float)   # shape (Z, T_total * k)
val_dev   = np.loadtxt(old_val_dev_path,   dtype=float)   # shape (Z, T_total)
val_ids   = np.loadtxt(old_val_ids_path,  dtype=int)      # shape (Z,)

print("July val_array shape:", val_array.shape)
print("July val_dev shape  :", val_dev.shape)
print("July val_ids shape  :", val_ids.shape)

# Infer T_total and reconstruct July train_array / train_dev
Z, total_flat = val_array.shape
k = mdl.k
T_total = total_flat // k
T_train = mdl.train_time_steps   # this was computed inside create_model_train_val

print(f"T_total (from val_array) = {T_total}, k = {k}, T_train = {T_train}")

# Reshape val_array to (Z, T_total, k)
val_array_3d = val_array.reshape(Z, T_total, k)

# July forecast split: train_array = first T_train time steps (for all experiments)
train_array = val_array_3d[:, :T_train, :].reshape(Z, T_train * k)

# July train_dev: first T_train time points, val_dev: all time points
train_dev = val_dev[:, :T_train]

print("Reconstructed July train_array shape:", train_array.shape)
print("Reconstructed July train_dev shape  :", train_dev.shape)

# -------------------------------------------------------------------
# 3) (Optional) Save the arrays again under the "current" prefix, if you want
#    to keep them for later sanity checks:
# -------------------------------------------------------------------
np.savetxt(f'{folder}model/{run_name}_val_array.txt', val_array, fmt='%f')
np.savetxt(f'{folder}model/{run_name}_val_dev.txt',   val_dev,   fmt='%f')
np.savetxt(f'{folder}model/{run_name}_val_ids.txt',   np.asarray(val_ids), fmt='%d')
np.savetxt(f'{folder}model/{run_name}_train_array.txt', train_array, fmt='%f')
np.savetxt(f'{folder}model/{run_name}_train_dev.txt',   train_dev,   fmt='%f')

# -------------------------------------------------------------------
# 4) Train model on the *July* arrays
# -------------------------------------------------------------------
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=1e-3,
        decay_steps=280,
        decay_rate=0.9,
        staircase=True
    )
(
    (losses_s_v_train, losses_neg_v_train, losses_c_train, losses_drop_c_train),
    (losses_s_v_val,   losses_neg_v_val,   losses_c_val,   losses_drop_c_val)
    ) = model.train_model(
        mdl, train_array, val_array=val_array,
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
        num_epochs=num_epochs, batch_size=batch_size, patience=patience,
        verbose=True,
        train_test_split=train_test_split,
        x_fold=x_fold
    )

for i in range(N_iter):
    lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(
        initial_learning_rate=1e-3,
        decay_steps=280,
        decay_rate=0.9,
        staircase=True
    )
    (
        (losses_s_v_train, losses_neg_v_train, losses_c_train, losses_drop_c_train),
        (losses_s_v_val,   losses_neg_v_val,   losses_c_val,   losses_drop_c_val)
    ) = model.train_model(
        mdl, train_array, val_array=val_array,
        optimizer=tf.keras.optimizers.Adam(learning_rate=lr_schedule),
        num_epochs=num_epochs, batch_size=batch_size, patience=patience,
        verbose=True,
        train_test_split=train_test_split,
        x_fold=x_fold
    )

    mdl_name = f'{folder}model/{run_name}_{str(i)}'
    mdl.save_model(model_name=mdl_name, verbose=True)
# Out:
# Physical GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# [process_data] detected OD mode (M28-style OD + DEV)
# Transport[15,49] = 1.0  EX_met__L_e_o
# Transport[12,84] = 1.0  EX_ile__L_e_o
# Transport[13,89] = 1.0  EX_leu__L_e_o
# Transport[9,96] = 1.0  EX_gln__L_e_o
# Transport[17,98] = 1.0  EX_pro__L_e_o
# Transport[23,103] = 1.0  EX_ade_e_o
# Transport[3,108] = 1.0  EX_ala__L_e_o
# Transport[4,109] = 1.0  EX_arg__L_e_o
# Transport[6,110] = 1.0  EX_asp__L_e_o
# Transport[2,112] = 1.0  EX_succ_e_o
# Transport[27,113] = 1.0  EX_thymd_e_o
# Transport[21,115] = 1.0  EX_tyr__L_e_o
# Transport[8,121] = 1.0  EX_glu__L_e_o
# Transport[24,125] = 1.0  EX_gua_e_o
# Transport[0,180] = 1.0  EX_glc__D_e_o
# Transport[26,186] = 1.0  EX_ura_e_o
# Transport[22,188] = 1.0  EX_val__L_e_o
# Transport[1,211] = 1.0  EX_xyl__D_e_o
# Transport[10,217] = 1.0  EX_gly_e_o
# Transport[14,219] = 1.0  EX_lys__L_e_o
# Transport[18,227] = 1.0  EX_ser__L_e_o
# Transport[20,229] = 1.0  EX_trp__L_e_o
# Transport[5,1459] = 1.0  EX_asn__L_e_o
# Transport[16,1489] = 1.0  EX_phe__L_e_o
# Transport[19,1490] = 1.0  EX_thr__L_e_o
# Transport[25,1524] = 1.0  EX_csn_e_o
# Transport[11,1533] = 1.0  EX_his__L_e_o
# Transport[7,1742] = 1.0  EX_cys__L_e_o
# Transport[28,2668] = 1.0  BIOMASS
# Transport[15,2730] = -1.0  EX_met__L_e_i
# Transport[12,2744] = -1.0  EX_ile__L_e_i
# Transport[13,2748] = -1.0  EX_leu__L_e_i
# Transport[9,2753] = -1.0  EX_gln__L_e_i
# Transport[17,2754] = -1.0  EX_pro__L_e_i
# Transport[23,2758] = -1.0  EX_ade_e_i
# Transport[3,2763] = -1.0  EX_ala__L_e_i
# Transport[4,2764] = -1.0  EX_arg__L_e_i
# Transport[6,2765] = -1.0  EX_asp__L_e_i
# Transport[2,2767] = -1.0  EX_succ_e_i
# Transport[27,2768] = -1.0  EX_thymd_e_i
# Transport[21,2770] = -1.0  EX_tyr__L_e_i
# Transport[8,2775] = -1.0  EX_glu__L_e_i
# Transport[24,2777] = -1.0  EX_gua_e_i
# Transport[0,2805] = -1.0  EX_glc__D_e_i
# Transport[26,2808] = -1.0  EX_ura_e_i
# Transport[22,2809] = -1.0  EX_val__L_e_i
# Transport[1,2819] = -1.0  EX_xyl__D_e_i
# Transport[10,2824] = -1.0  EX_gly_e_i
# Transport[14,2826] = -1.0  EX_lys__L_e_i
# Transport[18,2829] = -1.0  EX_ser__L_e_i
# Transport[20,2831] = -1.0  EX_trp__L_e_i
# Transport[5,3325] = -1.0  EX_asn__L_e_i
# Transport[16,3342] = -1.0  EX_phe__L_e_i
# Transport[19,3343] = -1.0  EX_thr__L_e_i
# Transport[25,3356] = -1.0  EX_csn_e_i
# Transport[11,3361] = -1.0  EX_his__L_e_i
# Transport[7,3446] = -1.0  EX_cys__L_e_i
# Transport shape: (29, 3682), Stoichiometry shape: (1877, 3682)
# Number of metabolites (k): 29, Number of fluxes (n): 3682
# Train shape: (280, 377)
# Val shape: (280, 580)
# -----------------------------MetabolicModel-----------------------------
# times: 0.32, 1.57, ..., 23.99
# metabolite_ids: ['glc__D_e', 'xyl__D_e', 'succ_e', 'ala__L_e', 'arg__L_e', 'asn__L_e', 'asp__L_e', 'cys__L_e', 'glu__L_e', 'gln__L_e', 'gly_e', 'his__L_e', 'ile__L_e', 'leu__L_e', 'lys__L_e', 'met__L_e', 'phe__L_e', 'pro__L_e', 'ser__L_e', 'thr__L_e', 'trp__L_e', 'tyr__L_e', 'val__L_e', 'ade_e', 'gua_e', 'csn_e', 'ura_e', 'thymd_e', 'BIOMASS']
# Total time step: 20
# Train time step: 13
# dt: [1.0000007 1.0000007 1.0000007 1.0000007 1.0000007 1.0000007 1.0000004
#  1.0000007 1.0000007 1.0000007 1.0000007 1.0000007 1.0000015 1.
#  1.0000015 1.        1.0000015 1.        1.0000015]
# Transport: (29, 3682)
# Stoichiometry: (1877, 3682)
# n: 3682
# k: 29
# Reaction ids: 3682
# Biomass id: BIOMASS_Ec_iML1515_core_75p37M
# Biomass flux index: 2668
# Lag Layer : Hidden size = [50] trainainle parameters = 1602
# Flux Layer : Hidden size = [500] trainainle parameters = 1859682
# Dropout Rate: 0.2
# Loss weight: [0.001, 1, 1, 1]
# Loss decay: [0, 0.5, 0.5, 1]
# train_test_split: forecast
# train_test_split: 13
# x_fold: 3
# ------------------------------------------------------------------------
#
# Loading July arrays from:
#    ./model_july31/M28_OD_20_forecast_val_array.txt
#    ./model_july31/M28_OD_20_forecast_val_dev.txt
#    ./model_july31/M28_OD_20_forecast_val_ids.txt
# July val_array shape: (280, 580)
# July val_dev shape  : (280, 20)
# July val_ids shape  : (280,)
# T_total (from val_array) = 20, k = 29, T_train = 13
# Reconstructed July train_array shape: (280, 377)
# Reconstructed July train_dev shape  : (280, 13)
#
# === Sanity check: training data ===
# C_train_all shape: (280, 13, 29)  (Z, T_train, k)
# Number of metabolites k = 29
# Number of time points in training trajectories = 13
# First 5 metabolite IDs (if available): ['glc__D_e', 'xyl__D_e', 'succ_e']
# Biomass metabolite ID (last column): BIOMASS
# C_train_all.shape: (280, 13, 29)
#
# Experiment 0 — first time points:
# t =   0.32  C[0,0,0:3] = [44.404972  0.        0.        0.        0.      ]  BIOMASS = 0.0313 OD = -2.4691
# t =   1.57  C[0,1,0:3] = [nan nan nan nan nan]  BIOMASS = 0.0313 OD = -2.4691
# t =   2.81  C[0,2,0:3] = [nan nan nan nan nan]  BIOMASS = 0.0323 OD = -2.4381
# t =   4.06  C[0,3,0:3] = [nan nan nan nan nan]  BIOMASS = 0.0335 OD = -2.4006
# t =   5.30  C[0,4,0:3] = [nan nan nan nan nan]  BIOMASS = 0.0360 OD = -2.3296
# t =   6.55  C[0,5,0:3] = [nan nan nan nan nan]  BIOMASS = 0.0466 OD = -2.0716
# t =   7.80  C[0,6,0:3] = [nan nan nan nan nan]  BIOMASS = 0.0800 OD = -1.5310
# t =   9.04  C[0,7,0:3] = [nan nan nan nan nan]  BIOMASS = 0.1627 OD = -0.8218
# t =  10.29  C[0,8,0:3] = [nan nan nan nan nan]  BIOMASS = 0.2954 OD = -0.2252
# t =  11.53  C[0,9,0:3] = [nan nan nan nan nan]  BIOMASS = 0.4163 OD = 0.1180
# t =  12.78  C[0,10,0:3] = [nan nan nan nan nan]  BIOMASS = 0.4244 OD = 0.1371
# t =  14.02  C[0,11,0:3] = [nan nan nan nan nan]  BIOMASS = 0.4377 OD = 0.1679
# t =  15.27  C[0,12,0:3] = [nan nan nan nan nan]  BIOMASS = 0.4504 OD = 0.1966
#
# === Sanity check: validation data ===
# C_val_all shape: (280, 20, 29)  (Z_val, T_val, k)
# === End sanity check ===
#
# [Epoch 1/1000] Train: s_v=1.6e+00, neg_v=3.0e-01, c=2.3e+00, drop_c=4.4e-02 | Val: s_v=6.5e-01, neg_v=1.1e-01, c=1.9e-01, drop_c=8.9e-03
# [Epoch 2/1000] Train: s_v=1.6e-01, neg_v=1.1e-01, c=2.2e-01, drop_c=2.8e-02 | Val: s_v=1.2e-01, neg_v=4.1e-02, c=2.5e-02, drop_c=1.0e-03
# [Epoch 3/1000] Train: s_v=8.3e-02, neg_v=7.0e-02, c=1.3e-01, drop_c=2.1e-02 | Val: s_v=3.0e-02, neg_v=2.6e-02, c=1.1e-02, drop_c=4.8e-04
# [Epoch 4/1000] Train: s_v=6.1e-02, neg_v=5.4e-02, c=1.1e-01, drop_c=1.7e-02 | Val: s_v=2.6e-02, neg_v=1.9e-02, c=1.1e-02, drop_c=1.5e-03
# [Epoch 5/1000] Train: s_v=5.4e-02, neg_v=4.4e-02, c=7.9e-02, drop_c=1.5e-02 | Val: s_v=2.1e-02, neg_v=1.7e-02, c=1.5e-02, drop_c=2.8e-04
# [Epoch 6/1000] Train: s_v=4.4e-02, neg_v=3.8e-02, c=6.9e-02, drop_c=1.4e-02 | Val: s_v=1.7e-02, neg_v=1.5e-02, c=1.3e-02, drop_c=7.1e-05
# [Epoch 7/1000] Train: s_v=4.1e-02, neg_v=3.4e-02, c=6.5e-02, drop_c=1.2e-02 | Val: s_v=1.7e-02, neg_v=1.5e-02, c=1.4e-02, drop_c=2.6e-05
# [Epoch 8/1000] Train: s_v=3.6e-02, neg_v=3.1e-02, c=5.3e-02, drop_c=1.0e-02 | Val: s_v=1.6e-02, neg_v=1.4e-02, c=9.5e-03, drop_c=2.7e-04
# [Epoch 9/1000] Train: s_v=3.2e-02, neg_v=2.9e-02, c=4.3e-02, drop_c=8.6e-03 | Val: s_v=1.5e-02, neg_v=1.3e-02, c=7.1e-03, drop_c=6.2e-05
# [Epoch 10/1000] Train: s_v=2.9e-02, neg_v=2.7e-02, c=3.8e-02, drop_c=7.9e-03 | Val: s_v=1.3e-02, neg_v=1.2e-02, c=7.0e-03, drop_c=3.4e-05
# [Epoch 11/1000] Train: s_v=2.6e-02, neg_v=2.5e-02, c=3.6e-02, drop_c=7.4e-03 | Val: s_v=1.1e-02, neg_v=1.2e-02, c=7.0e-03, drop_c=7.9e-05
# [Epoch 12/1000] Train: s_v=2.4e-02, neg_v=2.4e-02, c=3.3e-02, drop_c=7.4e-03 | Val: s_v=1.2e-02, neg_v=1.1e-02, c=7.4e-03, drop_c=9.3e-06
# [Epoch 13/1000] Train: s_v=2.2e-02, neg_v=2.3e-02, c=2.9e-02, drop_c=6.6e-03 | Val: s_v=1.1e-02, neg_v=1.1e-02, c=7.3e-03, drop_c=8.1e-06
# [Epoch 14/1000] Train: s_v=2.0e-02, neg_v=2.2e-02, c=2.3e-02, drop_c=5.7e-03 | Val: s_v=1.0e-02, neg_v=1.1e-02, c=5.1e-03, drop_c=5.2e-06
# [Epoch 15/1000] Train: s_v=1.9e-02, neg_v=2.1e-02, c=4.6e-02, drop_c=6.3e-03 | Val: s_v=9.6e-03, neg_v=1.0e-02, c=7.4e-03, drop_c=1.7e-06
# [Epoch 16/1000] Train: s_v=1.9e-02, neg_v=2.0e-02, c=2.4e-02, drop_c=6.2e-03 | Val: s_v=1.2e-02, neg_v=9.7e-03, c=5.1e-03, drop_c=2.6e-06
# [Epoch 17/1000] Train: s_v=1.8e-02, neg_v=1.9e-02, c=2.3e-02, drop_c=4.7e-03 | Val: s_v=9.7e-03, neg_v=9.4e-03, c=5.0e-03, drop_c=2.8e-06
# [Epoch 18/1000] Train: s_v=1.6e-02, neg_v=1.9e-02, c=1.9e-02, drop_c=3.9e-03 | Val: s_v=8.5e-03, neg_v=9.1e-03, c=5.1e-03, drop_c=3.6e-06
# [Epoch 19/1000] Train: s_v=1.5e-02, neg_v=1.8e-02, c=2.2e-02, drop_c=4.4e-03 | Val: s_v=8.3e-03, neg_v=8.8e-03, c=7.1e-03, drop_c=5.8e-05
# [Epoch 20/1000] Train: s_v=1.4e-02, neg_v=1.7e-02, c=2.2e-02, drop_c=4.4e-03 | Val: s_v=8.2e-03, neg_v=8.5e-03, c=5.3e-03, drop_c=5.7e-05
# [Epoch 21/1000] Train: s_v=1.4e-02, neg_v=1.6e-02, c=2.2e-02, drop_c=4.6e-03 | Val: s_v=8.1e-03, neg_v=8.3e-03, c=5.1e-03, drop_c=3.6e-06
# [Epoch 22/1000] Train: s_v=1.3e-02, neg_v=1.6e-02, c=1.9e-02, drop_c=3.7e-03 | Val: s_v=7.0e-03, neg_v=8.1e-03, c=5.8e-03, drop_c=2.1e-06
# [Epoch 23/1000] Train: s_v=1.2e-02, neg_v=1.5e-02, c=1.8e-02, drop_c=3.6e-03 | Val: s_v=7.0e-03, neg_v=7.9e-03, c=5.1e-03, drop_c=1.6e-06
# [Epoch 24/1000] Train: s_v=1.2e-02, neg_v=1.5e-02, c=1.9e-02, drop_c=3.6e-03 | Val: s_v=6.5e-03, neg_v=7.7e-03, c=5.3e-03, drop_c=3.9e-05
# [Epoch 25/1000] Train: s_v=1.1e-02, neg_v=1.5e-02, c=2.0e-02, drop_c=2.8e-03 | Val: s_v=6.8e-03, neg_v=7.6e-03, c=7.1e-03, drop_c=2.9e-06
# [Epoch 26/1000] Train: s_v=1.1e-02, neg_v=1.4e-02, c=1.7e-02, drop_c=3.0e-03 | Val: s_v=6.2e-03, neg_v=7.4e-03, c=4.9e-03, drop_c=8.5e-07
# [Epoch 27/1000] Train: s_v=1.1e-02, neg_v=1.4e-02, c=1.3e-02, drop_c=1.8e-03 | Val: s_v=6.5e-03, neg_v=7.3e-03, c=4.8e-03, drop_c=1.6e-06
# [Epoch 28/1000] Train: s_v=1.0e-02, neg_v=1.3e-02, c=1.3e-02, drop_c=2.4e-03 | Val: s_v=6.6e-03, neg_v=7.1e-03, c=5.3e-03, drop_c=8.6e-07
# [Epoch 29/1000] Train: s_v=1.1e-02, neg_v=1.3e-02, c=1.2e-02, drop_c=2.0e-03 | Val: s_v=6.1e-03, neg_v=7.1e-03, c=4.8e-03, drop_c=6.9e-07
# [Epoch 30/1000] Train: s_v=1.0e-02, neg_v=1.3e-02, c=1.3e-02, drop_c=2.1e-03 | Val: s_v=5.6e-03, neg_v=6.9e-03, c=5.0e-03, drop_c=1.0e-06
# [Epoch 31/1000] Train: s_v=9.4e-03, neg_v=1.3e-02, c=1.2e-02, drop_c=1.9e-03 | Val: s_v=5.7e-03, neg_v=6.8e-03, c=4.7e-03, drop_c=6.4e-07
# [Epoch 32/1000] Train: s_v=9.3e-03, neg_v=1.2e-02, c=1.3e-02, drop_c=1.8e-03 | Val: s_v=5.8e-03, neg_v=6.7e-03, c=5.1e-03, drop_c=9.6e-07
# [Epoch 33/1000] Train: s_v=9.1e-03, neg_v=1.2e-02, c=1.1e-02, drop_c=1.7e-03 | Val: s_v=5.4e-03, neg_v=6.6e-03, c=4.8e-03, drop_c=5.3e-07
# [Epoch 34/1000] Train: s_v=8.6e-03, neg_v=1.2e-02, c=1.2e-02, drop_c=1.4e-03 | Val: s_v=5.2e-03, neg_v=6.5e-03, c=5.1e-03, drop_c=5.4e-07
# [Epoch 35/1000] Train: s_v=8.4e-03, neg_v=1.2e-02, c=1.1e-02, drop_c=1.7e-03 | Val: s_v=6.0e-03, neg_v=6.4e-03, c=4.8e-03, drop_c=4.7e-07
# [Epoch 36/1000] Train: s_v=1.1e-02, neg_v=1.1e-02, c=1.1e-02, drop_c=1.3e-03 | Val: s_v=9.4e-03, neg_v=6.3e-03, c=4.8e-03, drop_c=4.9e-07
# [Epoch 37/1000] Train: s_v=1.8e-02, neg_v=1.1e-02, c=1.0e-02, drop_c=1.3e-03 | Val: s_v=8.1e-03, neg_v=6.3e-03, c=4.9e-03, drop_c=6.7e-07
# [Epoch 38/1000] Train: s_v=1.1e-02, neg_v=1.1e-02, c=1.0e-02, drop_c=1.5e-03 | Val: s_v=8.1e-03, neg_v=6.2e-03, c=4.7e-03, drop_c=4.8e-07
# [Epoch 39/1000] Train: s_v=9.1e-03, neg_v=1.1e-02, c=1.5e-02, drop_c=1.3e-03 | Val: s_v=5.0e-03, neg_v=6.1e-03, c=4.9e-03, drop_c=4.7e-07
# [Epoch 40/1000] Train: s_v=7.8e-03, neg_v=1.1e-02, c=1.1e-02, drop_c=1.3e-03 | Val: s_v=5.3e-03, neg_v=6.0e-03, c=5.4e-03, drop_c=5.2e-07
# [Epoch 41/1000] Train: s_v=8.3e-03, neg_v=1.0e-02, c=9.4e-03, drop_c=1.1e-03 | Val: s_v=8.3e-03, neg_v=6.0e-03, c=4.7e-03, drop_c=3.7e-07
# [Epoch 42/1000] Train: s_v=8.7e-03, neg_v=1.0e-02, c=9.4e-03, drop_c=1.2e-03 | Val: s_v=6.5e-03, neg_v=5.9e-03, c=4.8e-03, drop_c=4.6e-07
# [Epoch 43/1000] Train: s_v=1.1e-02, neg_v=9.8e-03, c=1.0e-02, drop_c=1.3e-03 | Val: s_v=4.9e-03, neg_v=5.9e-03, c=4.8e-03, drop_c=5.6e-07
# [Epoch 44/1000] Train: s_v=9.4e-03, neg_v=9.7e-03, c=9.6e-03, drop_c=1.2e-03 | Val: s_v=3.2e-02, neg_v=5.8e-03, c=4.8e-03, drop_c=4.6e-07
# [Epoch 45/1000] Train: s_v=2.2e-02, neg_v=9.6e-03, c=1.1e-02, drop_c=1.3e-03 | Val: s_v=8.5e-03, neg_v=5.7e-03, c=4.9e-03, drop_c=5.0e-07
# [Epoch 46/1000] Train: s_v=1.1e-02, neg_v=9.5e-03, c=9.7e-03, drop_c=1.1e-03 | Val: s_v=4.6e-03, neg_v=5.7e-03, c=4.8e-03, drop_c=4.3e-07
# [Epoch 47/1000] Train: s_v=6.7e-03, neg_v=9.3e-03, c=1.0e-02, drop_c=1.3e-03 | Val: s_v=5.9e-03, neg_v=5.6e-03, c=4.8e-03, drop_c=4.4e-07
# [Epoch 48/1000] Train: s_v=7.4e-03, neg_v=9.1e-03, c=1.0e-02, drop_c=1.2e-03 | Val: s_v=7.4e-03, neg_v=5.6e-03, c=5.5e-03, drop_c=4.5e-06
# [Epoch 49/1000] Train: s_v=1.0e-02, neg_v=9.0e-03, c=1.0e-02, drop_c=1.5e-03 | Val: s_v=6.3e-03, neg_v=5.5e-03, c=4.8e-03, drop_c=4.1e-07
# [Epoch 50/1000] Train: s_v=7.4e-03, neg_v=8.9e-03, c=1.0e-02, drop_c=9.9e-04 | Val: s_v=6.7e-03, neg_v=5.5e-03, c=4.7e-03, drop_c=4.0e-07
# [Epoch 51/1000] Train: s_v=8.3e-03, neg_v=8.8e-03, c=9.6e-03, drop_c=1.1e-03 | Val: s_v=4.3e-03, neg_v=5.4e-03, c=4.8e-03, drop_c=5.0e-07
# [Epoch 52/1000] Train: s_v=7.4e-03, neg_v=8.6e-03, c=1.0e-02, drop_c=9.0e-04 | Val: s_v=1.1e-02, neg_v=5.3e-03, c=5.2e-03, drop_c=4.8e-07
# [Epoch 53/1000] Train: s_v=1.0e-02, neg_v=8.5e-03, c=1.1e-02, drop_c=1.1e-03 | Val: s_v=4.2e-03, neg_v=5.3e-03, c=4.7e-03, drop_c=3.6e-07
# [Epoch 54/1000] Train: s_v=6.2e-03, neg_v=8.4e-03, c=1.1e-02, drop_c=1.0e-03 | Val: s_v=4.0e-03, neg_v=5.3e-03, c=5.0e-03, drop_c=4.5e-07
# [Epoch 55/1000] Train: s_v=5.6e-03, neg_v=8.3e-03, c=9.8e-03, drop_c=1.2e-03 | Val: s_v=3.6e-03, neg_v=5.3e-03, c=5.0e-03, drop_c=3.9e-07
# [Epoch 56/1000] Train: s_v=5.4e-03, neg_v=8.1e-03, c=8.8e-03, drop_c=7.8e-04 | Val: s_v=3.4e-03, neg_v=5.2e-03, c=4.6e-03, drop_c=4.2e-07
# [Epoch 57/1000] Train: s_v=5.2e-03, neg_v=8.1e-03, c=9.4e-03, drop_c=1.0e-03 | Val: s_v=3.2e-03, neg_v=5.2e-03, c=4.7e-03, drop_c=3.8e-07
# [Epoch 58/1000] Train: s_v=5.1e-03, neg_v=8.0e-03, c=9.1e-03, drop_c=9.4e-04 | Val: s_v=3.3e-03, neg_v=5.1e-03, c=5.0e-03, drop_c=5.8e-07
# [Epoch 59/1000] Train: s_v=5.1e-03, neg_v=7.9e-03, c=9.1e-03, drop_c=1.0e-03 | Val: s_v=3.3e-03, neg_v=5.2e-03, c=4.8e-03, drop_c=4.1e-07
# [Epoch 60/1000] Train: s_v=5.0e-03, neg_v=7.8e-03, c=8.6e-03, drop_c=1.1e-03 | Val: s_v=3.3e-03, neg_v=5.1e-03, c=4.7e-03, drop_c=4.5e-07
# [Epoch 61/1000] Train: s_v=4.9e-03, neg_v=7.7e-03, c=9.1e-03, drop_c=8.8e-04 | Val: s_v=3.1e-03, neg_v=5.0e-03, c=4.6e-03, drop_c=4.1e-07
# [Epoch 62/1000] Train: s_v=4.7e-03, neg_v=7.5e-03, c=1.1e-02, drop_c=1.1e-03 | Val: s_v=3.0e-03, neg_v=5.0e-03, c=5.3e-03, drop_c=6.8e-07
# [Epoch 63/1000] Train: s_v=4.7e-03, neg_v=7.6e-03, c=9.2e-03, drop_c=1.1e-03 | Val: s_v=3.1e-03, neg_v=5.0e-03, c=5.0e-03, drop_c=4.3e-07
# [Epoch 64/1000] Train: s_v=4.7e-03, neg_v=7.4e-03, c=8.4e-03, drop_c=8.7e-04 | Val: s_v=3.4e-03, neg_v=5.0e-03, c=4.7e-03, drop_c=3.4e-07
# [Epoch 65/1000] Train: s_v=5.0e-03, neg_v=7.4e-03, c=9.3e-03, drop_c=7.9e-04 | Val: s_v=3.0e-03, neg_v=4.9e-03, c=4.8e-03, drop_c=3.2e-07
# [Epoch 66/1000] Train: s_v=4.8e-03, neg_v=7.2e-03, c=1.4e-02, drop_c=1.3e-03 | Val: s_v=2.9e-03, neg_v=4.9e-03, c=5.8e-03, drop_c=8.1e-06
# [Epoch 67/1000] Train: s_v=4.7e-03, neg_v=7.2e-03, c=8.0e-03, drop_c=9.5e-04 | Val: s_v=3.5e-03, neg_v=4.8e-03, c=4.7e-03, drop_c=3.4e-07
# [Epoch 68/1000] Train: s_v=4.8e-03, neg_v=7.2e-03, c=8.3e-03, drop_c=6.5e-04 | Val: s_v=3.0e-03, neg_v=4.8e-03, c=4.8e-03, drop_c=4.7e-07
# [Epoch 69/1000] Train: s_v=5.2e-03, neg_v=7.0e-03, c=8.6e-03, drop_c=9.3e-04 | Val: s_v=4.5e-03, neg_v=4.8e-03, c=4.7e-03, drop_c=3.6e-07
# [Epoch 70/1000] Train: s_v=5.7e-03, neg_v=7.0e-03, c=7.9e-03, drop_c=7.0e-04 | Val: s_v=4.4e-03, neg_v=4.7e-03, c=4.7e-03, drop_c=4.0e-07
# [Epoch 71/1000] Train: s_v=4.5e-03, neg_v=6.9e-03, c=8.0e-03, drop_c=5.6e-04 | Val: s_v=2.9e-03, neg_v=4.7e-03, c=4.6e-03, drop_c=3.7e-07
# [Epoch 72/1000] Train: s_v=4.2e-03, neg_v=6.8e-03, c=8.5e-03, drop_c=8.5e-04 | Val: s_v=2.7e-03, neg_v=4.7e-03, c=4.7e-03, drop_c=3.9e-07
# [Epoch 73/1000] Train: s_v=4.1e-03, neg_v=6.7e-03, c=8.0e-03, drop_c=7.0e-04 | Val: s_v=2.6e-03, neg_v=4.6e-03, c=4.6e-03, drop_c=3.9e-07
# [Epoch 74/1000] Train: s_v=4.3e-03, neg_v=6.6e-03, c=9.3e-03, drop_c=9.6e-04 | Val: s_v=3.0e-03, neg_v=4.6e-03, c=5.2e-03, drop_c=4.8e-07
# [Epoch 75/1000] Train: s_v=4.1e-03, neg_v=6.6e-03, c=9.9e-03, drop_c=7.6e-04 | Val: s_v=2.6e-03, neg_v=4.6e-03, c=5.2e-03, drop_c=5.0e-07
# [Epoch 76/1000] Train: s_v=3.9e-03, neg_v=6.5e-03, c=1.0e-02, drop_c=8.4e-04 | Val: s_v=2.5e-03, neg_v=4.5e-03, c=4.8e-03, drop_c=3.7e-07
# [Epoch 77/1000] Train: s_v=4.0e-03, neg_v=6.5e-03, c=8.8e-03, drop_c=7.6e-04 | Val: s_v=2.8e-03, neg_v=4.5e-03, c=4.7e-03, drop_c=3.6e-07
# [Epoch 78/1000] Train: s_v=3.9e-03, neg_v=6.4e-03, c=8.7e-03, drop_c=7.7e-04 | Val: s_v=2.5e-03, neg_v=4.5e-03, c=4.6e-03, drop_c=3.2e-07
# [Epoch 79/1000] Train: s_v=3.8e-03, neg_v=6.4e-03, c=7.2e-03, drop_c=5.5e-04 | Val: s_v=2.4e-03, neg_v=4.4e-03, c=4.6e-03, drop_c=2.9e-07
# [Epoch 80/1000] Train: s_v=3.7e-03, neg_v=6.3e-03, c=8.5e-03, drop_c=6.8e-04 | Val: s_v=2.4e-03, neg_v=4.4e-03, c=4.8e-03, drop_c=4.3e-07
# [Epoch 81/1000] Train: s_v=3.7e-03, neg_v=6.1e-03, c=8.8e-03, drop_c=6.2e-04 | Val: s_v=2.4e-03, neg_v=4.3e-03, c=5.0e-03, drop_c=1.2e-06
# [Epoch 82/1000] Train: s_v=3.7e-03, neg_v=6.1e-03, c=7.2e-03, drop_c=7.6e-04 | Val: s_v=2.9e-03, neg_v=4.3e-03, c=4.6e-03, drop_c=3.0e-07
# [Epoch 83/1000] Train: s_v=4.2e-03, neg_v=6.0e-03, c=9.3e-03, drop_c=7.8e-04 | Val: s_v=2.4e-03, neg_v=4.3e-03, c=4.7e-03, drop_c=2.6e-07
# [Epoch 84/1000] Train: s_v=3.9e-03, neg_v=6.1e-03, c=8.0e-03, drop_c=5.7e-04 | Val: s_v=2.4e-03, neg_v=4.2e-03, c=4.6e-03, drop_c=3.7e-07
# [Epoch 85/1000] Train: s_v=3.8e-03, neg_v=5.9e-03, c=7.7e-03, drop_c=4.9e-04 | Val: s_v=2.3e-03, neg_v=4.2e-03, c=4.6e-03, drop_c=3.5e-07
# [Epoch 86/1000] Train: s_v=3.5e-03, neg_v=5.9e-03, c=8.0e-03, drop_c=5.9e-04 | Val: s_v=2.3e-03, neg_v=4.2e-03, c=4.7e-03, drop_c=3.6e-07
# [Epoch 87/1000] Train: s_v=3.4e-03, neg_v=5.9e-03, c=7.2e-03, drop_c=6.2e-04 | Val: s_v=2.2e-03, neg_v=4.1e-03, c=4.6e-03, drop_c=3.6e-07
# [Epoch 88/1000] Train: s_v=3.3e-03, neg_v=5.8e-03, c=8.6e-03, drop_c=6.4e-04 | Val: s_v=2.2e-03, neg_v=4.1e-03, c=4.9e-03, drop_c=3.8e-07
# [Epoch 89/1000] Train: s_v=3.4e-03, neg_v=5.8e-03, c=7.5e-03, drop_c=5.8e-04 | Val: s_v=2.3e-03, neg_v=4.1e-03, c=4.6e-03, drop_c=3.3e-07
# [Epoch 90/1000] Train: s_v=3.6e-03, neg_v=5.7e-03, c=7.2e-03, drop_c=4.8e-04 | Val: s_v=2.2e-03, neg_v=4.0e-03, c=4.6e-03, drop_c=3.9e-07
# [Epoch 91/1000] Train: s_v=3.2e-03, neg_v=5.5e-03, c=8.0e-03, drop_c=6.1e-04 | Val: s_v=2.1e-03, neg_v=4.0e-03, c=4.9e-03, drop_c=5.2e-07
# [Epoch 92/1000] Train: s_v=3.5e-03, neg_v=5.6e-03, c=7.7e-03, drop_c=6.1e-04 | Val: s_v=2.5e-03, neg_v=4.0e-03, c=4.6e-03, drop_c=4.7e-07
# [Epoch 93/1000] Train: s_v=3.3e-03, neg_v=5.5e-03, c=8.1e-03, drop_c=6.5e-04 | Val: s_v=2.2e-03, neg_v=3.9e-03, c=4.8e-03, drop_c=4.5e-07
# [Epoch 94/1000] Train: s_v=4.2e-03, neg_v=5.5e-03, c=8.2e-03, drop_c=4.6e-04 | Val: s_v=4.5e-03, neg_v=3.9e-03, c=4.6e-03, drop_c=3.8e-07
# [Epoch 95/1000] Train: s_v=3.4e-03, neg_v=5.4e-03, c=8.1e-03, drop_c=5.4e-04 | Val: s_v=2.0e-03, neg_v=3.9e-03, c=4.6e-03, drop_c=3.9e-07
# [Epoch 96/1000] Train: s_v=3.2e-03, neg_v=5.4e-03, c=7.7e-03, drop_c=5.5e-04 | Val: s_v=2.2e-03, neg_v=3.9e-03, c=4.6e-03, drop_c=3.8e-07
# [Epoch 97/1000] Train: s_v=3.2e-03, neg_v=5.3e-03, c=7.2e-03, drop_c=4.2e-04 | Val: s_v=2.0e-03, neg_v=3.8e-03, c=4.6e-03, drop_c=3.8e-07
# [Epoch 98/1000] Train: s_v=3.3e-03, neg_v=5.2e-03, c=7.5e-03, drop_c=4.2e-04 | Val: s_v=4.8e-03, neg_v=3.8e-03, c=4.6e-03, drop_c=3.3e-07
# [Epoch 99/1000] Train: s_v=4.0e-03, neg_v=5.3e-03, c=7.0e-03, drop_c=4.5e-04 | Val: s_v=2.3e-03, neg_v=3.8e-03, c=4.6e-03, drop_c=3.5e-07
# [Epoch 100/1000] Train: s_v=3.3e-03, neg_v=5.2e-03, c=7.7e-03, drop_c=6.3e-04 | Val: s_v=2.2e-03, neg_v=3.7e-03, c=4.7e-03, drop_c=4.2e-07
# [Epoch 101/1000] Train: s_v=3.3e-03, neg_v=5.1e-03, c=7.9e-03, drop_c=6.3e-04 | Val: s_v=2.2e-03, neg_v=3.7e-03, c=4.5e-03, drop_c=3.1e-07
# [Epoch 102/1000] Train: s_v=3.3e-03, neg_v=5.1e-03, c=7.4e-03, drop_c=4.7e-04 | Val: s_v=2.1e-03, neg_v=3.7e-03, c=4.6e-03, drop_c=3.6e-07
# [Epoch 103/1000] Train: s_v=3.4e-03, neg_v=5.0e-03, c=7.6e-03, drop_c=7.9e-04 | Val: s_v=2.6e-03, neg_v=3.7e-03, c=4.7e-03, drop_c=2.5e-07
# [Epoch 104/1000] Train: s_v=3.6e-03, neg_v=4.9e-03, c=9.3e-03, drop_c=4.3e-04 | Val: s_v=1.9e-03, neg_v=3.6e-03, c=4.7e-03, drop_c=4.6e-07
# [Epoch 105/1000] Train: s_v=3.2e-03, neg_v=5.0e-03, c=8.6e-03, drop_c=4.9e-04 | Val: s_v=2.1e-03, neg_v=3.6e-03, c=4.6e-03, drop_c=3.1e-07
# [Epoch 106/1000] Train: s_v=3.3e-03, neg_v=4.9e-03, c=6.9e-03, drop_c=4.6e-04 | Val: s_v=2.4e-03, neg_v=3.6e-03, c=4.5e-03, drop_c=3.1e-07
# [Epoch 107/1000] Train: s_v=3.1e-03, neg_v=4.9e-03, c=7.5e-03, drop_c=4.5e-04 | Val: s_v=4.5e-03, neg_v=3.6e-03, c=4.6e-03, drop_c=3.6e-07
# [Epoch 108/1000] Train: s_v=6.1e-03, neg_v=4.9e-03, c=7.1e-03, drop_c=5.6e-04 | Val: s_v=1.1e-02, neg_v=3.5e-03, c=4.6e-03, drop_c=3.0e-07
# [Epoch 109/1000] Train: s_v=6.9e-03, neg_v=4.8e-03, c=7.2e-03, drop_c=4.9e-04 | Val: s_v=2.2e-03, neg_v=3.5e-03, c=4.7e-03, drop_c=3.6e-07
# [Epoch 110/1000] Train: s_v=4.3e-03, neg_v=4.7e-03, c=7.3e-03, drop_c=3.1e-04 | Val: s_v=4.1e-03, neg_v=3.5e-03, c=4.6e-03, drop_c=3.6e-07
# [Epoch 111/1000] Train: s_v=4.9e-03, neg_v=4.7e-03, c=7.8e-03, drop_c=5.4e-04 | Val: s_v=6.0e-03, neg_v=3.4e-03, c=4.6e-03, drop_c=3.9e-07
# [Epoch 112/1000] Train: s_v=9.4e-03, neg_v=4.7e-03, c=7.3e-03, drop_c=5.1e-04 | Val: s_v=7.0e-03, neg_v=3.4e-03, c=4.5e-03, drop_c=3.2e-07
# [Epoch 113/1000] Train: s_v=1.1e-02, neg_v=4.6e-03, c=9.9e-03, drop_c=5.4e-04 | Val: s_v=7.6e-03, neg_v=3.4e-03, c=5.2e-03, drop_c=1.9e-06
# [Epoch 114/1000] Train: s_v=5.6e-03, neg_v=4.6e-03, c=6.9e-03, drop_c=5.2e-04 | Val: s_v=1.3e-02, neg_v=3.4e-03, c=4.6e-03, drop_c=3.7e-07
# [Epoch 115/1000] Train: s_v=5.5e-03, neg_v=4.5e-03, c=7.3e-03, drop_c=4.2e-04 | Val: s_v=2.6e-03, neg_v=3.3e-03, c=4.5e-03, drop_c=3.5e-07
# [Epoch 116/1000] Train: s_v=3.3e-03, neg_v=4.5e-03, c=8.0e-03, drop_c=4.4e-04 | Val: s_v=1.8e-03, neg_v=3.3e-03, c=4.6e-03, drop_c=3.7e-07
# [Epoch 117/1000] Train: s_v=2.7e-03, neg_v=4.5e-03, c=7.1e-03, drop_c=4.3e-04 | Val: s_v=1.7e-03, neg_v=3.3e-03, c=4.5e-03, drop_c=3.2e-07
# [Epoch 118/1000] Train: s_v=2.6e-03, neg_v=4.4e-03, c=7.5e-03, drop_c=3.7e-04 | Val: s_v=1.6e-03, neg_v=3.3e-03, c=4.6e-03, drop_c=3.0e-07
# [Epoch 119/1000] Train: s_v=2.5e-03, neg_v=4.4e-03, c=6.5e-03, drop_c=4.6e-04 | Val: s_v=2.1e-03, neg_v=3.2e-03, c=4.5e-03, drop_c=3.3e-07
# [Epoch 120/1000] Train: s_v=2.7e-03, neg_v=4.3e-03, c=7.3e-03, drop_c=4.2e-04 | Val: s_v=1.7e-03, neg_v=3.2e-03, c=4.6e-03, drop_c=3.1e-07
# [Epoch 121/1000] Train: s_v=2.6e-03, neg_v=4.3e-03, c=7.0e-03, drop_c=3.9e-04 | Val: s_v=2.1e-03, neg_v=3.2e-03, c=4.6e-03, drop_c=3.5e-07
# [Epoch 122/1000] Train: s_v=2.5e-03, neg_v=4.3e-03, c=7.8e-03, drop_c=4.3e-04 | Val: s_v=1.5e-03, neg_v=3.1e-03, c=4.7e-03, drop_c=3.7e-07
# [Epoch 123/1000] Train: s_v=2.5e-03, neg_v=4.2e-03, c=7.2e-03, drop_c=4.4e-04 | Val: s_v=1.6e-03, neg_v=3.1e-03, c=4.6e-03, drop_c=3.7e-07
# [Epoch 124/1000] Train: s_v=2.4e-03, neg_v=4.2e-03, c=6.9e-03, drop_c=3.6e-04 | Val: s_v=1.5e-03, neg_v=3.1e-03, c=4.5e-03, drop_c=3.5e-07
# [Epoch 125/1000] Train: s_v=2.3e-03, neg_v=4.1e-03, c=7.3e-03, drop_c=8.6e-04 | Val: s_v=1.5e-03, neg_v=3.1e-03, c=4.5e-03, drop_c=3.1e-07
# [Epoch 126/1000] Train: s_v=2.3e-03, neg_v=4.1e-03, c=7.5e-03, drop_c=3.4e-04 | Val: s_v=1.5e-03, neg_v=3.0e-03, c=4.7e-03, drop_c=4.7e-07
# [Epoch 127/1000] Train: s_v=2.3e-03, neg_v=4.0e-03, c=7.7e-03, drop_c=6.0e-04 | Val: s_v=1.5e-03, neg_v=3.0e-03, c=4.5e-03, drop_c=4.2e-07
# [Epoch 128/1000] Train: s_v=2.3e-03, neg_v=4.0e-03, c=7.5e-03, drop_c=3.5e-04 | Val: s_v=1.5e-03, neg_v=3.0e-03, c=4.5e-03, drop_c=4.3e-07
# [Epoch 129/1000] Train: s_v=2.3e-03, neg_v=4.0e-03, c=7.0e-03, drop_c=4.4e-04 | Val: s_v=1.5e-03, neg_v=2.9e-03, c=4.6e-03, drop_c=4.6e-07
# [Epoch 130/1000] Train: s_v=2.3e-03, neg_v=3.9e-03, c=6.8e-03, drop_c=4.5e-04 | Val: s_v=1.4e-03, neg_v=2.9e-03, c=4.6e-03, drop_c=4.2e-07
# [Epoch 131/1000] Train: s_v=2.2e-03, neg_v=3.8e-03, c=7.4e-03, drop_c=3.3e-04 | Val: s_v=1.4e-03, neg_v=2.9e-03, c=4.6e-03, drop_c=3.6e-07
# [Epoch 132/1000] Train: s_v=2.2e-03, neg_v=3.8e-03, c=7.1e-03, drop_c=3.2e-04 | Val: s_v=1.4e-03, neg_v=2.8e-03, c=4.6e-03, drop_c=4.2e-07
# [Epoch 133/1000] Train: s_v=2.2e-03, neg_v=3.8e-03, c=7.4e-03, drop_c=4.0e-04 | Val: s_v=1.4e-03, neg_v=2.8e-03, c=4.6e-03, drop_c=3.8e-07
# [Epoch 134/1000] Train: s_v=2.2e-03, neg_v=3.8e-03, c=6.8e-03, drop_c=3.0e-04 | Val: s_v=1.4e-03, neg_v=2.8e-03, c=4.8e-03, drop_c=4.6e-07
# [Epoch 135/1000] Train: s_v=2.2e-03, neg_v=3.7e-03, c=6.6e-03, drop_c=4.1e-04 | Val: s_v=1.4e-03, neg_v=2.7e-03, c=4.5e-03, drop_c=3.2e-07
# [Epoch 136/1000] Train: s_v=2.1e-03, neg_v=3.7e-03, c=7.5e-03, drop_c=4.4e-04 | Val: s_v=1.4e-03, neg_v=2.7e-03, c=4.5e-03, drop_c=3.7e-07
# [Epoch 137/1000] Train: s_v=2.1e-03, neg_v=3.6e-03, c=7.3e-03, drop_c=2.9e-04 | Val: s_v=1.4e-03, neg_v=2.7e-03, c=4.7e-03, drop_c=4.6e-07
# [Epoch 138/1000] Train: s_v=2.3e-03, neg_v=3.7e-03, c=6.8e-03, drop_c=3.9e-04 | Val: s_v=2.5e-03, neg_v=2.6e-03, c=4.5e-03, drop_c=3.7e-07
# [Epoch 139/1000] Train: s_v=2.3e-03, neg_v=3.6e-03, c=7.4e-03, drop_c=3.1e-04 | Val: s_v=1.4e-03, neg_v=2.6e-03, c=4.6e-03, drop_c=4.4e-07
# [Epoch 140/1000] Train: s_v=2.1e-03, neg_v=3.5e-03, c=7.0e-03, drop_c=3.8e-04 | Val: s_v=1.3e-03, neg_v=2.6e-03, c=4.5e-03, drop_c=4.3e-07
# [Epoch 141/1000] Train: s_v=2.1e-03, neg_v=3.5e-03, c=7.0e-03, drop_c=4.3e-04 | Val: s_v=1.3e-03, neg_v=2.5e-03, c=4.8e-03, drop_c=4.8e-07
# [Epoch 142/1000] Train: s_v=2.1e-03, neg_v=3.4e-03, c=7.2e-03, drop_c=4.1e-04 | Val: s_v=1.3e-03, neg_v=2.5e-03, c=4.6e-03, drop_c=4.9e-07
# [Epoch 143/1000] Train: s_v=2.0e-03, neg_v=3.4e-03, c=6.9e-03, drop_c=3.7e-04 | Val: s_v=1.3e-03, neg_v=2.5e-03, c=4.5e-03, drop_c=4.4e-07
# [Epoch 144/1000] Train: s_v=2.0e-03, neg_v=3.4e-03, c=6.8e-03, drop_c=3.5e-04 | Val: s_v=1.3e-03, neg_v=2.4e-03, c=4.5e-03, drop_c=4.6e-07
# [Epoch 145/1000] Train: s_v=2.0e-03, neg_v=3.4e-03, c=6.6e-03, drop_c=2.6e-04 | Val: s_v=1.3e-03, neg_v=2.4e-03, c=4.5e-03, drop_c=4.2e-07
# [Epoch 146/1000] Train: s_v=2.0e-03, neg_v=3.3e-03, c=7.7e-03, drop_c=3.4e-04 | Val: s_v=1.3e-03, neg_v=2.4e-03, c=4.8e-03, drop_c=5.9e-07
# [Epoch 147/1000] Train: s_v=2.0e-03, neg_v=3.3e-03, c=6.5e-03, drop_c=2.8e-04 | Val: s_v=1.3e-03, neg_v=2.3e-03, c=4.5e-03, drop_c=3.7e-07
# [Epoch 148/1000] Train: s_v=2.0e-03, neg_v=3.2e-03, c=6.6e-03, drop_c=2.1e-04 | Val: s_v=1.3e-03, neg_v=2.3e-03, c=4.5e-03, drop_c=5.0e-07
# [Epoch 149/1000] Train: s_v=2.0e-03, neg_v=3.2e-03, c=7.2e-03, drop_c=2.9e-04 | Val: s_v=1.3e-03, neg_v=2.3e-03, c=4.5e-03, drop_c=5.2e-07
# [Epoch 150/1000] Train: s_v=2.1e-03, neg_v=3.2e-03, c=6.5e-03, drop_c=4.0e-04 | Val: s_v=1.5e-03, neg_v=2.3e-03, c=4.5e-03, drop_c=4.7e-07
# [Epoch 151/1000] Train: s_v=2.0e-03, neg_v=3.2e-03, c=6.4e-03, drop_c=3.3e-04 | Val: s_v=1.3e-03, neg_v=2.3e-03, c=4.5e-03, drop_c=4.4e-07
# [Epoch 152/1000] Train: s_v=2.0e-03, neg_v=3.1e-03, c=6.6e-03, drop_c=3.3e-04 | Val: s_v=1.3e-03, neg_v=2.2e-03, c=4.5e-03, drop_c=5.0e-07
# [Epoch 153/1000] Train: s_v=2.3e-03, neg_v=3.1e-03, c=7.1e-03, drop_c=2.9e-04 | Val: s_v=2.6e-03, neg_v=2.2e-03, c=4.5e-03, drop_c=5.0e-07
# [Epoch 154/1000] Train: s_v=4.8e-03, neg_v=3.1e-03, c=6.7e-03, drop_c=3.0e-04 | Val: s_v=2.2e-03, neg_v=2.2e-03, c=4.4e-03, drop_c=3.8e-07
# [Epoch 155/1000] Train: s_v=3.3e-03, neg_v=3.1e-03, c=6.5e-03, drop_c=2.6e-04 | Val: s_v=3.4e-03, neg_v=2.2e-03, c=4.5e-03, drop_c=5.1e-07
# [Epoch 156/1000] Train: s_v=2.4e-03, neg_v=3.1e-03, c=7.4e-03, drop_c=3.0e-04 | Val: s_v=1.7e-03, neg_v=2.2e-03, c=4.6e-03, drop_c=4.2e-07
# [Epoch 157/1000] Train: s_v=2.0e-03, neg_v=3.1e-03, c=6.3e-03, drop_c=3.3e-04 | Val: s_v=1.3e-03, neg_v=2.2e-03, c=4.4e-03, drop_c=3.5e-07
# [Epoch 158/1000] Train: s_v=1.9e-03, neg_v=3.0e-03, c=6.9e-03, drop_c=3.7e-04 | Val: s_v=1.2e-03, neg_v=2.2e-03, c=4.6e-03, drop_c=4.4e-07
# [Epoch 159/1000] Train: s_v=1.9e-03, neg_v=3.0e-03, c=6.8e-03, drop_c=3.0e-04 | Val: s_v=1.2e-03, neg_v=2.1e-03, c=4.5e-03, drop_c=4.6e-07
# [Epoch 160/1000] Train: s_v=2.0e-03, neg_v=3.0e-03, c=6.9e-03, drop_c=2.7e-04 | Val: s_v=1.3e-03, neg_v=2.1e-03, c=4.5e-03, drop_c=4.2e-07
# [Epoch 161/1000] Train: s_v=2.0e-03, neg_v=3.0e-03, c=7.0e-03, drop_c=2.7e-04 | Val: s_v=1.4e-03, neg_v=2.1e-03, c=4.7e-03, drop_c=4.3e-07
# [Epoch 162/1000] Train: s_v=1.9e-03, neg_v=2.9e-03, c=6.8e-03, drop_c=4.0e-04 | Val: s_v=1.2e-03, neg_v=2.1e-03, c=4.5e-03, drop_c=4.6e-07
# [Epoch 163/1000] Train: s_v=1.9e-03, neg_v=2.9e-03, c=7.3e-03, drop_c=3.4e-04 | Val: s_v=1.2e-03, neg_v=2.1e-03, c=4.5e-03, drop_c=4.7e-07
# [Epoch 164/1000] Train: s_v=2.0e-03, neg_v=2.9e-03, c=6.4e-03, drop_c=3.7e-04 | Val: s_v=1.3e-03, neg_v=2.1e-03, c=4.4e-03, drop_c=4.1e-07
# [Epoch 165/1000] Train: s_v=1.8e-03, neg_v=2.9e-03, c=6.2e-03, drop_c=2.8e-04 | Val: s_v=1.1e-03, neg_v=2.1e-03, c=4.4e-03, drop_c=4.0e-07
# [Epoch 166/1000] Train: s_v=1.8e-03, neg_v=2.9e-03, c=6.4e-03, drop_c=3.0e-04 | Val: s_v=1.1e-03, neg_v=2.1e-03, c=4.4e-03, drop_c=3.9e-07
# [Epoch 167/1000] Train: s_v=1.7e-03, neg_v=2.9e-03, c=6.6e-03, drop_c=1.9e-04 | Val: s_v=1.1e-03, neg_v=2.1e-03, c=4.4e-03, drop_c=3.7e-07
# [Epoch 168/1000] Train: s_v=1.7e-03, neg_v=2.9e-03, c=6.2e-03, drop_c=3.7e-04 | Val: s_v=1.1e-03, neg_v=2.1e-03, c=4.4e-03, drop_c=4.4e-07
# [Epoch 169/1000] Train: s_v=1.7e-03, neg_v=2.9e-03, c=5.9e-03, drop_c=2.4e-04 | Val: s_v=1.1e-03, neg_v=2.1e-03, c=4.4e-03, drop_c=4.7e-07
# [Epoch 170/1000] Train: s_v=1.7e-03, neg_v=2.8e-03, c=6.7e-03, drop_c=3.4e-04 | Val: s_v=1.1e-03, neg_v=2.0e-03, c=4.7e-03, drop_c=6.0e-07
# [Epoch 171/1000] Train: s_v=1.7e-03, neg_v=2.8e-03, c=6.0e-03, drop_c=2.5e-04 | Val: s_v=1.1e-03, neg_v=2.0e-03, c=4.4e-03, drop_c=4.0e-07
# [Epoch 172/1000] Train: s_v=1.7e-03, neg_v=2.8e-03, c=6.4e-03, drop_c=1.9e-04 | Val: s_v=1.1e-03, neg_v=2.0e-03, c=4.5e-03, drop_c=4.9e-07
# [Epoch 173/1000] Train: s_v=1.7e-03, neg_v=2.8e-03, c=7.1e-03, drop_c=2.9e-04 | Val: s_v=1.1e-03, neg_v=2.0e-03, c=4.4e-03, drop_c=4.9e-07
# [Epoch 174/1000] Train: s_v=1.7e-03, neg_v=2.8e-03, c=6.2e-03, drop_c=3.7e-04 | Val: s_v=1.6e-03, neg_v=2.0e-03, c=4.4e-03, drop_c=4.1e-07
# [Epoch 175/1000] Train: s_v=1.9e-03, neg_v=2.8e-03, c=7.1e-03, drop_c=2.9e-04 | Val: s_v=1.4e-03, neg_v=2.0e-03, c=4.6e-03, drop_c=4.9e-07
# [Epoch 176/1000] Train: s_v=2.1e-03, neg_v=2.8e-03, c=6.9e-03, drop_c=2.0e-04 | Val: s_v=1.1e-03, neg_v=2.0e-03, c=4.5e-03, drop_c=5.0e-07
# [Epoch 177/1000] Train: s_v=1.8e-03, neg_v=2.8e-03, c=6.4e-03, drop_c=2.2e-04 | Val: s_v=1.1e-03, neg_v=2.0e-03, c=4.4e-03, drop_c=4.6e-07
# [Epoch 178/1000] Train: s_v=1.7e-03, neg_v=2.8e-03, c=6.5e-03, drop_c=2.5e-04 | Val: s_v=1.3e-03, neg_v=2.0e-03, c=4.6e-03, drop_c=5.1e-07
# [Epoch 179/1000] Train: s_v=2.2e-03, neg_v=2.7e-03, c=5.6e-03, drop_c=2.1e-04 | Val: s_v=1.7e-03, neg_v=2.0e-03, c=4.4e-03, drop_c=3.4e-07
# [Epoch 180/1000] Train: s_v=2.0e-03, neg_v=2.7e-03, c=6.0e-03, drop_c=2.3e-04 | Val: s_v=1.5e-03, neg_v=2.0e-03, c=4.6e-03, drop_c=6.4e-07
# [Epoch 181/1000] Train: s_v=1.8e-03, neg_v=2.7e-03, c=6.3e-03, drop_c=3.2e-04 | Val: s_v=1.5e-03, neg_v=2.0e-03, c=4.4e-03, drop_c=4.9e-07
# [Epoch 182/1000] Train: s_v=2.2e-03, neg_v=2.7e-03, c=6.1e-03, drop_c=2.5e-04 | Val: s_v=2.5e-03, neg_v=2.0e-03, c=4.4e-03, drop_c=4.5e-07
# [Epoch 183/1000] Train: s_v=4.6e-03, neg_v=2.7e-03, c=6.4e-03, drop_c=2.5e-04 | Val: s_v=5.1e-03, neg_v=1.9e-03, c=4.4e-03, drop_c=5.2e-07
# [Epoch 184/1000] Train: s_v=4.0e-03, neg_v=2.6e-03, c=6.9e-03, drop_c=3.6e-04 | Val: s_v=4.0e-03, neg_v=1.9e-03, c=4.4e-03, drop_c=4.7e-07
# [Epoch 185/1000] Train: s_v=2.7e-03, neg_v=2.6e-03, c=6.2e-03, drop_c=2.5e-04 | Val: s_v=1.5e-03, neg_v=1.9e-03, c=4.4e-03, drop_c=5.5e-07
# [Epoch 186/1000] Train: s_v=1.9e-03, neg_v=2.6e-03, c=6.0e-03, drop_c=2.5e-04 | Val: s_v=1.1e-03, neg_v=1.9e-03, c=4.4e-03, drop_c=5.3e-07
# [Epoch 187/1000] Train: s_v=1.7e-03, neg_v=2.6e-03, c=6.7e-03, drop_c=2.5e-04 | Val: s_v=1.0e-03, neg_v=1.9e-03, c=4.7e-03, drop_c=4.8e-07
# [Epoch 188/1000] Train: s_v=1.6e-03, neg_v=2.6e-03, c=6.4e-03, drop_c=2.9e-04 | Val: s_v=1.0e-03, neg_v=1.9e-03, c=4.5e-03, drop_c=4.2e-07
# [Epoch 189/1000] Train: s_v=1.6e-03, neg_v=2.6e-03, c=6.2e-03, drop_c=2.2e-04 | Val: s_v=1.1e-03, neg_v=1.9e-03, c=4.4e-03, drop_c=4.7e-07
# [Epoch 190/1000] Train: s_v=2.2e-03, neg_v=2.6e-03, c=6.7e-03, drop_c=2.0e-04 | Val: s_v=2.1e-03, neg_v=1.9e-03, c=4.4e-03, drop_c=4.3e-07
# [Epoch 191/1000] Train: s_v=1.9e-03, neg_v=2.6e-03, c=6.6e-03, drop_c=2.1e-04 | Val: s_v=1.1e-03, neg_v=1.9e-03, c=4.5e-03, drop_c=4.6e-07
# [Epoch 192/1000] Train: s_v=1.6e-03, neg_v=2.6e-03, c=6.6e-03, drop_c=1.2e-04 | Val: s_v=1.1e-03, neg_v=1.9e-03, c=4.6e-03, drop_c=4.6e-07
# [Epoch 193/1000] Train: s_v=1.5e-03, neg_v=2.5e-03, c=6.1e-03, drop_c=3.2e-04 | Val: s_v=1.0e-03, neg_v=1.9e-03, c=4.4e-03, drop_c=4.7e-07
# [Epoch 194/1000] Train: s_v=1.5e-03, neg_v=2.6e-03, c=6.8e-03, drop_c=2.5e-04 | Val: s_v=9.7e-04, neg_v=1.9e-03, c=4.5e-03, drop_c=5.0e-07
# [Epoch 195/1000] Train: s_v=1.5e-03, neg_v=2.5e-03, c=6.7e-03, drop_c=2.8e-04 | Val: s_v=9.7e-04, neg_v=1.9e-03, c=4.4e-03, drop_c=4.9e-07
# [Epoch 196/1000] Train: s_v=1.5e-03, neg_v=2.5e-03, c=5.7e-03, drop_c=2.9e-04 | Val: s_v=9.4e-04, neg_v=1.9e-03, c=4.4e-03, drop_c=4.6e-07
# [Epoch 197/1000] Train: s_v=1.5e-03, neg_v=2.5e-03, c=6.3e-03, drop_c=2.1e-04 | Val: s_v=9.3e-04, neg_v=1.8e-03, c=4.5e-03, drop_c=5.5e-07
# [Epoch 198/1000] Train: s_v=1.5e-03, neg_v=2.5e-03, c=6.2e-03, drop_c=2.8e-04 | Val: s_v=9.3e-04, neg_v=1.8e-03, c=4.4e-03, drop_c=5.1e-07
# [Epoch 199/1000] Train: s_v=1.4e-03, neg_v=2.5e-03, c=6.3e-03, drop_c=2.2e-04 | Val: s_v=9.4e-04, neg_v=1.8e-03, c=4.5e-03, drop_c=5.8e-07
# [Epoch 200/1000] Train: s_v=1.4e-03, neg_v=2.5e-03, c=6.4e-03, drop_c=3.0e-04 | Val: s_v=9.3e-04, neg_v=1.8e-03, c=4.7e-03, drop_c=6.2e-07
# [Epoch 201/1000] Train: s_v=1.4e-03, neg_v=2.5e-03, c=6.4e-03, drop_c=2.3e-04 | Val: s_v=9.0e-04, neg_v=1.8e-03, c=4.4e-03, drop_c=5.0e-07
# [Epoch 202/1000] Train: s_v=1.4e-03, neg_v=2.5e-03, c=6.1e-03, drop_c=2.6e-04 | Val: s_v=9.0e-04, neg_v=1.8e-03, c=4.4e-03, drop_c=5.6e-07
# [Epoch 203/1000] Train: s_v=1.4e-03, neg_v=2.4e-03, c=6.4e-03, drop_c=2.5e-04 | Val: s_v=8.9e-04, neg_v=1.8e-03, c=4.3e-03, drop_c=4.7e-07
# [Epoch 204/1000] Train: s_v=1.4e-03, neg_v=2.5e-03, c=6.1e-03, drop_c=2.5e-04 | Val: s_v=8.8e-04, neg_v=1.8e-03, c=4.3e-03, drop_c=4.9e-07
# [Epoch 205/1000] Train: s_v=1.4e-03, neg_v=2.5e-03, c=5.9e-03, drop_c=1.9e-04 | Val: s_v=8.9e-04, neg_v=1.8e-03, c=4.4e-03, drop_c=5.5e-07
# [Epoch 206/1000] Train: s_v=1.4e-03, neg_v=2.4e-03, c=5.8e-03, drop_c=1.8e-04 | Val: s_v=8.7e-04, neg_v=1.8e-03, c=4.3e-03, drop_c=4.5e-07
# [Epoch 207/1000] Train: s_v=1.4e-03, neg_v=2.4e-03, c=5.8e-03, drop_c=1.7e-04 | Val: s_v=8.8e-04, neg_v=1.8e-03, c=4.4e-03, drop_c=5.4e-07
# [Epoch 208/1000] Train: s_v=1.4e-03, neg_v=2.4e-03, c=5.9e-03, drop_c=2.2e-04 | Val: s_v=8.8e-04, neg_v=1.8e-03, c=4.4e-03, drop_c=5.0e-07
# [Epoch 209/1000] Train: s_v=1.4e-03, neg_v=2.4e-03, c=6.9e-03, drop_c=2.4e-04 | Val: s_v=9.8e-04, neg_v=1.8e-03, c=5.2e-03, drop_c=7.3e-07
# [Epoch 210/1000] Train: s_v=1.4e-03, neg_v=2.4e-03, c=6.5e-03, drop_c=2.1e-04 | Val: s_v=8.7e-04, neg_v=1.8e-03, c=4.3e-03, drop_c=3.6e-07
# [Epoch 211/1000] Train: s_v=1.4e-03, neg_v=2.4e-03, c=5.8e-03, drop_c=2.0e-04 | Val: s_v=8.6e-04, neg_v=1.7e-03, c=4.4e-03, drop_c=4.8e-07
# [Epoch 212/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=6.5e-03, drop_c=2.3e-04 | Val: s_v=8.7e-04, neg_v=1.7e-03, c=4.5e-03, drop_c=6.0e-07
# [Epoch 213/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=5.8e-03, drop_c=1.9e-04 | Val: s_v=8.6e-04, neg_v=1.7e-03, c=4.4e-03, drop_c=4.8e-07
# [Epoch 214/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=6.3e-03, drop_c=2.1e-04 | Val: s_v=8.6e-04, neg_v=1.7e-03, c=4.4e-03, drop_c=5.7e-07
# [Epoch 215/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=5.8e-03, drop_c=2.0e-04 | Val: s_v=8.6e-04, neg_v=1.7e-03, c=4.4e-03, drop_c=5.5e-07
# [Epoch 216/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=6.3e-03, drop_c=2.2e-04 | Val: s_v=8.5e-04, neg_v=1.7e-03, c=4.4e-03, drop_c=6.0e-07
# [Epoch 217/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=6.2e-03, drop_c=1.7e-04 | Val: s_v=8.5e-04, neg_v=1.7e-03, c=4.3e-03, drop_c=4.9e-07
# [Epoch 218/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=5.7e-03, drop_c=2.2e-04 | Val: s_v=8.3e-04, neg_v=1.7e-03, c=4.3e-03, drop_c=5.0e-07
# [Epoch 219/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=6.7e-03, drop_c=1.4e-04 | Val: s_v=8.5e-04, neg_v=1.7e-03, c=4.5e-03, drop_c=6.1e-07
# [Epoch 220/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=6.4e-03, drop_c=1.8e-04 | Val: s_v=8.9e-04, neg_v=1.7e-03, c=4.5e-03, drop_c=5.6e-07
# [Epoch 221/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=6.4e-03, drop_c=2.2e-04 | Val: s_v=8.3e-04, neg_v=1.7e-03, c=4.5e-03, drop_c=6.0e-07
# [Epoch 222/1000] Train: s_v=1.3e-03, neg_v=2.2e-03, c=5.9e-03, drop_c=1.8e-04 | Val: s_v=8.1e-04, neg_v=1.7e-03, c=4.4e-03, drop_c=6.2e-07
# [Epoch 223/1000] Train: s_v=1.3e-03, neg_v=2.3e-03, c=6.5e-03, drop_c=2.3e-04 | Val: s_v=8.3e-04, neg_v=1.7e-03, c=4.3e-03, drop_c=5.4e-07
# [Epoch 224/1000] Train: s_v=1.3e-03, neg_v=2.2e-03, c=6.0e-03, drop_c=2.2e-04 | Val: s_v=8.5e-04, neg_v=1.7e-03, c=4.5e-03, drop_c=6.2e-07
# [Epoch 225/1000] Train: s_v=1.3e-03, neg_v=2.2e-03, c=5.8e-03, drop_c=2.7e-04 | Val: s_v=8.0e-04, neg_v=1.7e-03, c=4.3e-03, drop_c=4.9e-07
# [Epoch 226/1000] Train: s_v=1.3e-03, neg_v=2.2e-03, c=5.8e-03, drop_c=1.4e-04 | Val: s_v=8.1e-04, neg_v=1.6e-03, c=4.4e-03, drop_c=6.3e-07
# [Epoch 227/1000] Train: s_v=1.3e-03, neg_v=2.2e-03, c=5.8e-03, drop_c=2.0e-04 | Val: s_v=8.0e-04, neg_v=1.6e-03, c=4.3e-03, drop_c=5.2e-07
# [Epoch 228/1000] Train: s_v=1.2e-03, neg_v=2.2e-03, c=5.9e-03, drop_c=1.5e-04 | Val: s_v=7.9e-04, neg_v=1.6e-03, c=4.4e-03, drop_c=5.9e-07
# [Epoch 229/1000] Train: s_v=1.2e-03, neg_v=2.2e-03, c=5.6e-03, drop_c=1.7e-04 | Val: s_v=8.0e-04, neg_v=1.6e-03, c=4.3e-03, drop_c=5.1e-07
# [Epoch 230/1000] Train: s_v=1.2e-03, neg_v=2.2e-03, c=6.2e-03, drop_c=1.9e-04 | Val: s_v=7.9e-04, neg_v=1.6e-03, c=4.5e-03, drop_c=7.0e-07
# [Epoch 231/1000] Train: s_v=1.2e-03, neg_v=2.1e-03, c=6.1e-03, drop_c=1.9e-04 | Val: s_v=7.8e-04, neg_v=1.6e-03, c=4.4e-03, drop_c=5.3e-07
# [Epoch 232/1000] Train: s_v=1.2e-03, neg_v=2.2e-03, c=5.7e-03, drop_c=2.0e-04 | Val: s_v=7.9e-04, neg_v=1.6e-03, c=4.3e-03, drop_c=5.2e-07
# [Epoch 233/1000] Train: s_v=1.2e-03, neg_v=2.1e-03, c=5.7e-03, drop_c=1.9e-04 | Val: s_v=7.8e-04, neg_v=1.6e-03, c=4.3e-03, drop_c=4.6e-07
# [Epoch 234/1000] Train: s_v=1.2e-03, neg_v=2.2e-03, c=6.0e-03, drop_c=1.6e-04 | Val: s_v=7.9e-04, neg_v=1.6e-03, c=4.6e-03, drop_c=6.8e-07
# [Epoch 235/1000] Train: s_v=1.2e-03, neg_v=2.1e-03, c=6.0e-03, drop_c=2.0e-04 | Val: s_v=7.8e-04, neg_v=1.6e-03, c=4.3e-03, drop_c=5.3e-07
# [Epoch 236/1000] Train: s_v=1.2e-03, neg_v=2.1e-03, c=5.9e-03, drop_c=2.2e-04 | Val: s_v=7.7e-04, neg_v=1.6e-03, c=4.4e-03, drop_c=5.0e-07
# [Epoch 237/1000] Train: s_v=1.2e-03, neg_v=2.1e-03, c=6.4e-03, drop_c=1.8e-04 | Val: s_v=8.1e-04, neg_v=1.6e-03, c=4.4e-03, drop_c=5.5e-07
# [Epoch 238/1000] Train: s_v=1.2e-03, neg_v=2.1e-03, c=5.7e-03, drop_c=1.8e-04 | Val: s_v=8.2e-04, neg_v=1.6e-03, c=4.3e-03, drop_c=5.7e-07
# [Epoch 239/1000] Train: s_v=1.2e-03, neg_v=2.1e-03, c=6.0e-03, drop_c=1.8e-04 | Val: s_v=7.7e-04, neg_v=1.6e-03, c=4.4e-03, drop_c=6.2e-07
# [Epoch 240/1000] Train: s_v=1.3e-03, neg_v=2.1e-03, c=5.9e-03, drop_c=2.1e-04 | Val: s_v=1.0e-03, neg_v=1.5e-03, c=4.3e-03, drop_c=5.4e-07
# [Epoch 241/1000] Train: s_v=1.3e-03, neg_v=2.1e-03, c=5.5e-03, drop_c=1.5e-04 | Val: s_v=7.7e-04, neg_v=1.5e-03, c=4.4e-03, drop_c=6.0e-07
# [Epoch 242/1000] Train: s_v=1.3e-03, neg_v=2.1e-03, c=6.0e-03, drop_c=1.5e-04 | Val: s_v=8.8e-04, neg_v=1.5e-03, c=4.4e-03, drop_c=5.8e-07
# [Epoch 243/1000] Train: s_v=1.3e-03, neg_v=2.0e-03, c=6.1e-03, drop_c=2.0e-04 | Val: s_v=9.1e-04, neg_v=1.5e-03, c=4.4e-03, drop_c=4.5e-07
# [Epoch 244/1000] Train: s_v=1.3e-03, neg_v=2.1e-03, c=6.0e-03, drop_c=1.8e-04 | Val: s_v=1.1e-03, neg_v=1.5e-03, c=4.4e-03, drop_c=6.3e-07
# [Epoch 245/1000] Train: s_v=1.4e-03, neg_v=2.0e-03, c=6.5e-03, drop_c=2.0e-04 | Val: s_v=8.2e-04, neg_v=1.5e-03, c=4.4e-03, drop_c=5.4e-07
# [Epoch 246/1000] Train: s_v=1.2e-03, neg_v=2.0e-03, c=6.1e-03, drop_c=2.2e-04 | Val: s_v=8.4e-04, neg_v=1.5e-03, c=4.3e-03, drop_c=4.4e-07
# [Epoch 247/1000] Train: s_v=1.2e-03, neg_v=2.0e-03, c=5.5e-03, drop_c=1.3e-04 | Val: s_v=1.1e-03, neg_v=1.5e-03, c=4.4e-03, drop_c=5.2e-07
# [Epoch 248/1000] Train: s_v=1.4e-03, neg_v=2.0e-03, c=5.7e-03, drop_c=1.4e-04 | Val: s_v=8.9e-04, neg_v=1.5e-03, c=4.3e-03, drop_c=4.8e-07
# [Epoch 249/1000] Train: s_v=1.2e-03, neg_v=2.0e-03, c=5.8e-03, drop_c=1.6e-04 | Val: s_v=7.2e-04, neg_v=1.5e-03, c=4.3e-03, drop_c=4.8e-07
# [Epoch 250/1000] Train: s_v=1.1e-03, neg_v=2.0e-03, c=6.0e-03, drop_c=1.4e-04 | Val: s_v=7.7e-04, neg_v=1.5e-03, c=4.4e-03, drop_c=5.6e-07
# [Epoch 251/1000] Train: s_v=1.1e-03, neg_v=2.0e-03, c=5.7e-03, drop_c=1.7e-04 | Val: s_v=7.2e-04, neg_v=1.5e-03, c=4.3e-03, drop_c=5.4e-07
# [Epoch 252/1000] Train: s_v=1.1e-03, neg_v=2.0e-03, c=5.5e-03, drop_c=1.6e-04 | Val: s_v=7.2e-04, neg_v=1.5e-03, c=4.3e-03, drop_c=5.0e-07
# [Epoch 253/1000] Train: s_v=1.1e-03, neg_v=2.0e-03, c=5.9e-03, drop_c=1.6e-04 | Val: s_v=7.1e-04, neg_v=1.5e-03, c=4.3e-03, drop_c=5.7e-07
# [Epoch 254/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=5.5e-03, drop_c=1.4e-04 | Val: s_v=7.1e-04, neg_v=1.4e-03, c=4.4e-03, drop_c=5.9e-07
# [Epoch 255/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=5.7e-03, drop_c=2.2e-04 | Val: s_v=7.2e-04, neg_v=1.4e-03, c=4.4e-03, drop_c=5.2e-07
# [Epoch 256/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=5.4e-03, drop_c=1.7e-04 | Val: s_v=7.1e-04, neg_v=1.4e-03, c=4.4e-03, drop_c=5.4e-07
# [Epoch 257/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=5.4e-03, drop_c=1.6e-04 | Val: s_v=7.0e-04, neg_v=1.4e-03, c=4.3e-03, drop_c=4.6e-07
# [Epoch 258/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=6.6e-03, drop_c=1.8e-04 | Val: s_v=7.0e-04, neg_v=1.4e-03, c=4.6e-03, drop_c=6.2e-07
# [Epoch 259/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=5.9e-03, drop_c=2.2e-04 | Val: s_v=7.0e-04, neg_v=1.4e-03, c=4.3e-03, drop_c=5.0e-07
# [Epoch 260/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=5.9e-03, drop_c=2.1e-04 | Val: s_v=7.1e-04, neg_v=1.4e-03, c=4.3e-03, drop_c=5.5e-07
# [Epoch 261/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=5.5e-03, drop_c=2.0e-04 | Val: s_v=6.9e-04, neg_v=1.4e-03, c=4.2e-03, drop_c=4.3e-07
# [Epoch 262/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=5.7e-03, drop_c=1.7e-04 | Val: s_v=6.8e-04, neg_v=1.4e-03, c=4.3e-03, drop_c=5.0e-07
# [Epoch 263/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=5.6e-03, drop_c=1.2e-04 | Val: s_v=6.8e-04, neg_v=1.4e-03, c=4.3e-03, drop_c=5.8e-07
# [Epoch 264/1000] Train: s_v=1.1e-03, neg_v=1.9e-03, c=6.7e-03, drop_c=1.3e-04 | Val: s_v=6.8e-04, neg_v=1.4e-03, c=4.7e-03, drop_c=8.8e-07
# [Epoch 265/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=5.6e-03, drop_c=2.0e-04 | Val: s_v=6.7e-04, neg_v=1.4e-03, c=4.3e-03, drop_c=4.8e-07
# [Epoch 266/1000] Train: s_v=1.0e-03, neg_v=1.9e-03, c=5.6e-03, drop_c=1.4e-04 | Val: s_v=6.7e-04, neg_v=1.4e-03, c=4.3e-03, drop_c=4.7e-07
# [Epoch 267/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=5.7e-03, drop_c=1.4e-04 | Val: s_v=6.7e-04, neg_v=1.4e-03, c=4.2e-03, drop_c=5.0e-07
# [Epoch 268/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=5.8e-03, drop_c=1.3e-04 | Val: s_v=6.7e-04, neg_v=1.4e-03, c=4.3e-03, drop_c=5.0e-07
# [Epoch 269/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=5.5e-03, drop_c=1.2e-04 | Val: s_v=6.7e-04, neg_v=1.3e-03, c=4.2e-03, drop_c=4.7e-07
# [Epoch 270/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=5.8e-03, drop_c=2.3e-04 | Val: s_v=6.7e-04, neg_v=1.3e-03, c=4.3e-03, drop_c=5.4e-07
# [Epoch 271/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=5.5e-03, drop_c=1.7e-04 | Val: s_v=6.6e-04, neg_v=1.3e-03, c=4.3e-03, drop_c=5.0e-07
# [Epoch 272/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=6.2e-03, drop_c=1.7e-04 | Val: s_v=6.6e-04, neg_v=1.3e-03, c=4.5e-03, drop_c=7.0e-07
# [Epoch 273/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=5.9e-03, drop_c=2.1e-04 | Val: s_v=6.5e-04, neg_v=1.3e-03, c=4.3e-03, drop_c=4.5e-07
# [Epoch 274/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=5.4e-03, drop_c=1.9e-04 | Val: s_v=6.6e-04, neg_v=1.3e-03, c=4.4e-03, drop_c=6.2e-07
# [Epoch 275/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=5.6e-03, drop_c=1.4e-04 | Val: s_v=6.8e-04, neg_v=1.3e-03, c=4.2e-03, drop_c=5.1e-07
# [Epoch 276/1000] Train: s_v=1.0e-03, neg_v=1.8e-03, c=5.7e-03, drop_c=1.9e-04 | Val: s_v=6.6e-04, neg_v=1.3e-03, c=4.4e-03, drop_c=7.0e-07
# [Epoch 277/1000] Train: s_v=1.0e-03, neg_v=1.7e-03, c=7.5e-03, drop_c=2.7e-04 | Val: s_v=6.5e-04, neg_v=1.3e-03, c=4.5e-03, drop_c=4.9e-07
# [Epoch 278/1000] Train: s_v=9.9e-04, neg_v=1.7e-03, c=5.9e-03, drop_c=1.5e-04 | Val: s_v=6.5e-04, neg_v=1.3e-03, c=4.3e-03, drop_c=4.5e-07
# [Epoch 279/1000] Train: s_v=1.0e-03, neg_v=1.7e-03, c=5.2e-03, drop_c=2.1e-04 | Val: s_v=6.5e-04, neg_v=1.3e-03, c=4.3e-03, drop_c=4.2e-07
# [Epoch 280/1000] Train: s_v=1.0e-03, neg_v=1.7e-03, c=5.6e-03, drop_c=1.5e-04 | Val: s_v=6.5e-04, neg_v=1.3e-03, c=4.4e-03, drop_c=5.3e-07
# [Epoch 281/1000] Train: s_v=9.8e-04, neg_v=1.7e-03, c=5.9e-03, drop_c=1.4e-04 | Val: s_v=6.3e-04, neg_v=1.3e-03, c=4.4e-03, drop_c=5.1e-07
# [Epoch 282/1000] Train: s_v=9.7e-04, neg_v=1.7e-03, c=6.2e-03, drop_c=1.6e-04 | Val: s_v=6.4e-04, neg_v=1.3e-03, c=4.4e-03, drop_c=4.6e-07
# [Epoch 283/1000] Train: s_v=9.8e-04, neg_v=1.7e-03, c=5.6e-03, drop_c=1.7e-04 | Val: s_v=6.4e-04, neg_v=1.3e-03, c=4.3e-03, drop_c=4.8e-07
# [Epoch 284/1000] Train: s_v=9.9e-04, neg_v=1.7e-03, c=5.6e-03, drop_c=1.5e-04 | Val: s_v=6.4e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=4.6e-07
# [Epoch 285/1000] Train: s_v=9.7e-04, neg_v=1.7e-03, c=5.6e-03, drop_c=1.1e-04 | Val: s_v=6.2e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=5.1e-07
# [Epoch 286/1000] Train: s_v=9.6e-04, neg_v=1.7e-03, c=5.7e-03, drop_c=1.5e-04 | Val: s_v=6.3e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=5.0e-07
# [Epoch 287/1000] Train: s_v=9.7e-04, neg_v=1.7e-03, c=5.5e-03, drop_c=1.3e-04 | Val: s_v=6.4e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=5.1e-07
# [Epoch 288/1000] Train: s_v=9.7e-04, neg_v=1.7e-03, c=5.5e-03, drop_c=1.9e-04 | Val: s_v=6.4e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=5.5e-07
# [Epoch 289/1000] Train: s_v=9.5e-04, neg_v=1.6e-03, c=5.7e-03, drop_c=1.2e-04 | Val: s_v=6.1e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=4.9e-07
# [Epoch 290/1000] Train: s_v=9.5e-04, neg_v=1.7e-03, c=5.4e-03, drop_c=1.3e-04 | Val: s_v=6.4e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=5.5e-07
# [Epoch 291/1000] Train: s_v=9.7e-04, neg_v=1.6e-03, c=5.5e-03, drop_c=1.5e-04 | Val: s_v=6.6e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=5.2e-07
# [Epoch 292/1000] Train: s_v=9.7e-04, neg_v=1.6e-03, c=5.4e-03, drop_c=1.5e-04 | Val: s_v=6.2e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=5.0e-07
# [Epoch 293/1000] Train: s_v=9.6e-04, neg_v=1.6e-03, c=5.5e-03, drop_c=1.6e-04 | Val: s_v=6.1e-04, neg_v=1.2e-03, c=4.2e-03, drop_c=4.5e-07
# [Epoch 294/1000] Train: s_v=9.4e-04, neg_v=1.6e-03, c=5.9e-03, drop_c=1.5e-04 | Val: s_v=6.1e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=5.7e-07
# [Epoch 295/1000] Train: s_v=9.3e-04, neg_v=1.6e-03, c=5.8e-03, drop_c=1.8e-04 | Val: s_v=6.1e-04, neg_v=1.2e-03, c=4.2e-03, drop_c=5.2e-07
# [Epoch 296/1000] Train: s_v=9.2e-04, neg_v=1.6e-03, c=6.1e-03, drop_c=1.2e-04 | Val: s_v=6.1e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=5.5e-07
# [Epoch 297/1000] Train: s_v=9.2e-04, neg_v=1.6e-03, c=5.5e-03, drop_c=1.3e-04 | Val: s_v=6.1e-04, neg_v=1.2e-03, c=4.2e-03, drop_c=5.6e-07
# [Epoch 298/1000] Train: s_v=9.2e-04, neg_v=1.6e-03, c=5.6e-03, drop_c=1.2e-04 | Val: s_v=6.1e-04, neg_v=1.2e-03, c=4.3e-03, drop_c=5.8e-07
# [Epoch 299/1000] Train: s_v=9.2e-04, neg_v=1.6e-03, c=6.1e-03, drop_c=8.3e-05 | Val: s_v=6.0e-04, neg_v=1.1e-03, c=4.3e-03, drop_c=5.8e-07
# [Epoch 300/1000] Train: s_v=9.1e-04, neg_v=1.6e-03, c=5.7e-03, drop_c=1.7e-04 | Val: s_v=6.1e-04, neg_v=1.1e-03, c=4.3e-03, drop_c=5.7e-07
# [Epoch 301/1000] Train: s_v=9.2e-04, neg_v=1.6e-03, c=5.1e-03, drop_c=1.2e-04 | Val: s_v=6.2e-04, neg_v=1.1e-03, c=4.3e-03, drop_c=6.1e-07
# [Epoch 302/1000] Train: s_v=1.0e-03, neg_v=1.5e-03, c=6.0e-03, drop_c=1.3e-04 | Val: s_v=6.1e-04, neg_v=1.1e-03, c=4.3e-03, drop_c=6.2e-07
# [Epoch 303/1000] Train: s_v=9.4e-04, neg_v=1.5e-03, c=5.6e-03, drop_c=1.7e-04 | Val: s_v=7.6e-04, neg_v=1.1e-03, c=4.2e-03, drop_c=5.3e-07
# [Epoch 304/1000] Train: s_v=9.4e-04, neg_v=1.5e-03, c=5.6e-03, drop_c=1.3e-04 | Val: s_v=6.3e-04, neg_v=1.1e-03, c=4.2e-03, drop_c=5.3e-07
# [Epoch 305/1000] Train: s_v=9.1e-04, neg_v=1.5e-03, c=5.8e-03, drop_c=1.5e-04 | Val: s_v=5.9e-04, neg_v=1.1e-03, c=4.2e-03, drop_c=5.9e-07
# ...
# [Epoch 307/1000] Train: s_v=5.7e-06, neg_v=2.3e-06, c=1.1e-03, drop_c=2.4e-05 | Val: s_v=5.0e-06, neg_v=9.0e-07, c=7.0e-04, drop_c=1.7e-06
# [Epoch 308/1000] Train: s_v=5.8e-06, neg_v=2.8e-06, c=9.4e-04, drop_c=2.4e-05 | Val: s_v=5.1e-06, neg_v=8.9e-07, c=7.1e-04, drop_c=1.4e-06
# [Epoch 309/1000] Train: s_v=5.7e-06, neg_v=2.5e-06, c=1.1e-03, drop_c=3.0e-05 | Val: s_v=5.1e-06, neg_v=7.6e-07, c=7.2e-04, drop_c=1.2e-06
# [Epoch 310/1000] Train: s_v=5.6e-06, neg_v=2.2e-06, c=1.1e-03, drop_c=2.2e-05 | Val: s_v=5.0e-06, neg_v=7.7e-07, c=7.2e-04, drop_c=1.4e-06
# [Epoch 311/1000] Train: s_v=5.7e-06, neg_v=2.3e-06, c=1.2e-03, drop_c=1.5e-05 | Val: s_v=5.0e-06, neg_v=8.3e-07, c=7.1e-04, drop_c=1.5e-06
# [Epoch 312/1000] Train: s_v=5.6e-06, neg_v=2.4e-06, c=1.0e-03, drop_c=3.1e-05 | Val: s_v=5.0e-06, neg_v=8.2e-07, c=7.0e-04, drop_c=1.6e-06
# [Epoch 313/1000] Train: s_v=5.5e-06, neg_v=2.2e-06, c=1.1e-03, drop_c=3.6e-05 | Val: s_v=4.9e-06, neg_v=7.9e-07, c=7.1e-04, drop_c=9.6e-07
# [Epoch 314/1000] Train: s_v=5.6e-06, neg_v=2.2e-06, c=1.0e-03, drop_c=1.7e-05 | Val: s_v=4.8e-06, neg_v=7.6e-07, c=7.1e-04, drop_c=1.0e-06
# [Epoch 315/1000] Train: s_v=5.6e-06, neg_v=3.0e-06, c=1.0e-03, drop_c=1.8e-05 | Val: s_v=4.9e-06, neg_v=7.6e-07, c=7.0e-04, drop_c=1.1e-06
# [Epoch 316/1000] Train: s_v=5.5e-06, neg_v=2.3e-06, c=1.0e-03, drop_c=1.8e-05 | Val: s_v=4.9e-06, neg_v=7.9e-07, c=7.2e-04, drop_c=1.8e-06
# [Epoch 317/1000] Train: s_v=5.7e-06, neg_v=2.4e-06, c=1.0e-03, drop_c=3.5e-05 | Val: s_v=4.8e-06, neg_v=8.7e-07, c=7.2e-04, drop_c=1.1e-06
# [Epoch 318/1000] Train: s_v=5.4e-06, neg_v=2.0e-06, c=9.9e-04, drop_c=1.7e-05 | Val: s_v=4.8e-06, neg_v=7.6e-07, c=7.0e-04, drop_c=1.7e-06
# [Epoch 319/1000] Train: s_v=5.6e-06, neg_v=2.2e-06, c=9.7e-04, drop_c=1.2e-05 | Val: s_v=5.0e-06, neg_v=8.7e-07, c=6.8e-04, drop_c=1.8e-06
# [Epoch 320/1000] Train: s_v=5.6e-06, neg_v=2.5e-06, c=1.2e-03, drop_c=2.0e-05 | Val: s_v=4.8e-06, neg_v=8.3e-07, c=7.0e-04, drop_c=3.0e-06
# [Epoch 321/1000] Train: s_v=5.4e-06, neg_v=2.3e-06, c=1.1e-03, drop_c=1.9e-05 | Val: s_v=4.7e-06, neg_v=8.0e-07, c=7.0e-04, drop_c=3.2e-06
# [Epoch 322/1000] Train: s_v=5.4e-06, neg_v=2.4e-06, c=1.1e-03, drop_c=3.4e-05 | Val: s_v=4.7e-06, neg_v=7.3e-07, c=7.3e-04, drop_c=3.4e-06
# [Epoch 323/1000] Train: s_v=5.4e-06, neg_v=2.1e-06, c=1.1e-03, drop_c=2.3e-05 | Val: s_v=4.7e-06, neg_v=7.3e-07, c=6.8e-04, drop_c=2.3e-06
# [Epoch 324/1000] Train: s_v=5.5e-06, neg_v=3.2e-06, c=9.1e-04, drop_c=3.2e-05 | Val: s_v=4.8e-06, neg_v=7.8e-07, c=6.9e-04, drop_c=1.5e-06
# [Epoch 325/1000] Train: s_v=5.4e-06, neg_v=2.5e-06, c=1.0e-03, drop_c=3.0e-05 | Val: s_v=4.7e-06, neg_v=7.5e-07, c=7.0e-04, drop_c=1.5e-06
# [Epoch 326/1000] Train: s_v=5.2e-06, neg_v=1.8e-06, c=1.0e-03, drop_c=1.5e-05 | Val: s_v=4.7e-06, neg_v=7.1e-07, c=6.9e-04, drop_c=1.8e-06
# [Epoch 327/1000] Train: s_v=5.4e-06, neg_v=2.7e-06, c=1.0e-03, drop_c=2.3e-05 | Val: s_v=4.6e-06, neg_v=6.6e-07, c=7.1e-04, drop_c=2.1e-06
# [Epoch 328/1000] Train: s_v=5.2e-06, neg_v=2.1e-06, c=1.0e-03, drop_c=2.7e-05 | Val: s_v=4.6e-06, neg_v=6.7e-07, c=7.0e-04, drop_c=1.8e-06
# [Epoch 329/1000] Train: s_v=5.4e-06, neg_v=2.3e-06, c=1.1e-03, drop_c=1.6e-05 | Val: s_v=4.6e-06, neg_v=6.8e-07, c=6.9e-04, drop_c=1.3e-06
# [Epoch 330/1000] Train: s_v=5.3e-06, neg_v=2.2e-06, c=1.0e-03, drop_c=3.4e-05 | Val: s_v=4.6e-06, neg_v=8.0e-07, c=6.9e-04, drop_c=1.7e-06
# [Epoch 331/1000] Train: s_v=5.3e-06, neg_v=2.4e-06, c=9.9e-04, drop_c=3.0e-05 | Val: s_v=4.7e-06, neg_v=7.8e-07, c=6.9e-04, drop_c=2.6e-06
# [Epoch 332/1000] Train: s_v=5.3e-06, neg_v=2.6e-06, c=9.0e-04, drop_c=2.4e-05 | Val: s_v=4.6e-06, neg_v=8.5e-07, c=6.9e-04, drop_c=1.1e-06
# [Epoch 333/1000] Train: s_v=5.3e-06, neg_v=2.6e-06, c=9.8e-04, drop_c=1.9e-05 | Val: s_v=4.7e-06, neg_v=8.2e-07, c=6.9e-04, drop_c=2.0e-06
# [Epoch 334/1000] Train: s_v=5.4e-06, neg_v=2.3e-06, c=9.5e-04, drop_c=1.9e-05 | Val: s_v=4.7e-06, neg_v=8.4e-07, c=6.7e-04, drop_c=1.3e-06
# [Epoch 335/1000] Train: s_v=5.3e-06, neg_v=2.1e-06, c=9.4e-04, drop_c=2.6e-05 | Val: s_v=4.6e-06, neg_v=7.4e-07, c=6.8e-04, drop_c=1.8e-06
# [Epoch 336/1000] Train: s_v=5.3e-06, neg_v=2.4e-06, c=1.1e-03, drop_c=1.8e-05 | Val: s_v=4.6e-06, neg_v=7.7e-07, c=6.8e-04, drop_c=1.6e-06
# [Epoch 337/1000] Train: s_v=5.3e-06, neg_v=2.2e-06, c=1.2e-03, drop_c=2.7e-05 | Val: s_v=4.6e-06, neg_v=8.0e-07, c=6.8e-04, drop_c=1.2e-06
# [Epoch 338/1000] Train: s_v=5.3e-06, neg_v=2.4e-06, c=1.2e-03, drop_c=2.3e-05 | Val: s_v=4.6e-06, neg_v=8.6e-07, c=6.9e-04, drop_c=1.3e-06
# [Epoch 339/1000] Train: s_v=5.3e-06, neg_v=2.4e-06, c=1.1e-03, drop_c=1.6e-05 | Val: s_v=4.6e-06, neg_v=8.3e-07, c=6.9e-04, drop_c=1.1e-06
# [Epoch 340/1000] Train: s_v=5.4e-06, neg_v=2.6e-06, c=1.0e-03, drop_c=2.4e-05 | Val: s_v=4.6e-06, neg_v=7.9e-07, c=6.8e-04, drop_c=9.4e-07
# [Epoch 341/1000] Train: s_v=5.3e-06, neg_v=2.4e-06, c=1.2e-03, drop_c=1.5e-05 | Val: s_v=4.5e-06, neg_v=7.0e-07, c=7.0e-04, drop_c=1.3e-06
# [Epoch 342/1000] Train: s_v=5.2e-06, neg_v=2.3e-06, c=1.0e-03, drop_c=2.0e-05 | Val: s_v=4.5e-06, neg_v=6.8e-07, c=6.9e-04, drop_c=1.4e-06
# [Epoch 343/1000] Train: s_v=5.2e-06, neg_v=2.5e-06, c=8.6e-04, drop_c=2.5e-05 | Val: s_v=4.5e-06, neg_v=7.2e-07, c=6.8e-04, drop_c=1.0e-06
# [Epoch 344/1000] Train: s_v=5.3e-06, neg_v=2.3e-06, c=9.5e-04, drop_c=2.2e-05 | Val: s_v=4.5e-06, neg_v=7.7e-07, c=6.8e-04, drop_c=1.0e-06
# [Epoch 345/1000] Train: s_v=5.2e-06, neg_v=2.2e-06, c=9.5e-04, drop_c=2.0e-05 | Val: s_v=4.5e-06, neg_v=7.1e-07, c=6.7e-04, drop_c=9.8e-07
# [Epoch 346/1000] Train: s_v=5.3e-06, neg_v=2.6e-06, c=1.0e-03, drop_c=1.3e-05 | Val: s_v=4.5e-06, neg_v=7.5e-07, c=6.8e-04, drop_c=1.3e-06
# [Epoch 347/1000] Train: s_v=5.1e-06, neg_v=2.1e-06, c=1.0e-03, drop_c=2.6e-05 | Val: s_v=4.5e-06, neg_v=7.3e-07, c=6.7e-04, drop_c=1.2e-06
# [Epoch 348/1000] Train: s_v=5.3e-06, neg_v=2.4e-06, c=9.0e-04, drop_c=2.3e-05 | Val: s_v=4.5e-06, neg_v=6.1e-07, c=6.8e-04, drop_c=1.1e-06
# [Epoch 349/1000] Train: s_v=5.1e-06, neg_v=1.9e-06, c=1.0e-03, drop_c=2.6e-05 | Val: s_v=4.4e-06, neg_v=6.1e-07, c=6.8e-04, drop_c=9.2e-07
# [Epoch 350/1000] Train: s_v=5.1e-06, neg_v=2.1e-06, c=1.0e-03, drop_c=1.4e-05 | Val: s_v=4.4e-06, neg_v=6.8e-07, c=6.8e-04, drop_c=2.0e-06
# [Epoch 351/1000] Train: s_v=5.1e-06, neg_v=2.2e-06, c=1.1e-03, drop_c=1.9e-05 | Val: s_v=4.4e-06, neg_v=6.4e-07, c=6.8e-04, drop_c=1.7e-06
# [Epoch 352/1000] Train: s_v=5.1e-06, neg_v=2.0e-06, c=8.6e-04, drop_c=1.4e-05 | Val: s_v=4.4e-06, neg_v=7.0e-07, c=6.8e-04, drop_c=9.8e-07
# [Epoch 353/1000] Train: s_v=5.2e-06, neg_v=2.5e-06, c=9.0e-04, drop_c=4.1e-05 | Val: s_v=4.5e-06, neg_v=7.2e-07, c=6.7e-04, drop_c=1.1e-06
# [Epoch 354/1000] Train: s_v=5.2e-06, neg_v=2.3e-06, c=1.1e-03, drop_c=2.6e-05 | Val: s_v=4.4e-06, neg_v=6.9e-07, c=6.8e-04, drop_c=1.3e-06
# [Epoch 355/1000] Train: s_v=5.1e-06, neg_v=2.3e-06, c=9.2e-04, drop_c=1.5e-05 | Val: s_v=4.4e-06, neg_v=6.8e-07, c=6.7e-04, drop_c=8.6e-07
# [Epoch 356/1000] Train: s_v=5.2e-06, neg_v=2.4e-06, c=8.9e-04, drop_c=1.7e-05 | Val: s_v=4.5e-06, neg_v=7.2e-07, c=6.7e-04, drop_c=7.5e-07
# [Epoch 357/1000] Train: s_v=5.2e-06, neg_v=2.2e-06, c=8.7e-04, drop_c=1.8e-05 | Val: s_v=4.4e-06, neg_v=6.4e-07, c=6.7e-04, drop_c=8.5e-07
# [Epoch 358/1000] Train: s_v=5.1e-06, neg_v=2.4e-06, c=1.1e-03, drop_c=2.8e-05 | Val: s_v=4.5e-06, neg_v=6.9e-07, c=6.7e-04, drop_c=8.0e-07
# [Epoch 359/1000] Train: s_v=5.1e-06, neg_v=2.0e-06, c=1.0e-03, drop_c=2.1e-05 | Val: s_v=4.5e-06, neg_v=7.4e-07, c=6.7e-04, drop_c=1.5e-06
# [Epoch 360/1000] Train: s_v=5.1e-06, neg_v=1.9e-06, c=9.2e-04, drop_c=1.8e-05 | Val: s_v=4.5e-06, neg_v=7.8e-07, c=6.9e-04, drop_c=1.1e-06
# [Epoch 361/1000] Train: s_v=5.1e-06, neg_v=2.3e-06, c=1.1e-03, drop_c=1.4e-05 | Val: s_v=4.4e-06, neg_v=7.5e-07, c=6.7e-04, drop_c=1.3e-06
# [Epoch 362/1000] Train: s_v=5.0e-06, neg_v=2.3e-06, c=1.1e-03, drop_c=2.7e-05 | Val: s_v=4.4e-06, neg_v=7.5e-07, c=6.7e-04, drop_c=9.4e-07
# [Epoch 363/1000] Train: s_v=4.9e-06, neg_v=1.8e-06, c=9.9e-04, drop_c=2.0e-05 | Val: s_v=4.4e-06, neg_v=6.9e-07, c=6.7e-04, drop_c=1.0e-06
# [Epoch 364/1000] Train: s_v=5.0e-06, neg_v=2.0e-06, c=1.0e-03, drop_c=2.4e-05 | Val: s_v=4.4e-06, neg_v=6.4e-07, c=6.7e-04, drop_c=1.2e-06
# [Epoch 365/1000] Train: s_v=5.0e-06, neg_v=1.6e-06, c=1.1e-03, drop_c=2.1e-05 | Val: s_v=4.4e-06, neg_v=6.5e-07, c=6.6e-04, drop_c=1.1e-06
# [Epoch 366/1000] Train: s_v=5.0e-06, neg_v=2.6e-06, c=9.6e-04, drop_c=2.0e-05 | Val: s_v=4.4e-06, neg_v=7.2e-07, c=6.6e-04, drop_c=1.4e-06
# [Epoch 367/1000] Train: s_v=5.1e-06, neg_v=2.2e-06, c=1.0e-03, drop_c=2.7e-05 | Val: s_v=4.3e-06, neg_v=6.6e-07, c=6.7e-04, drop_c=1.0e-06
# [Epoch 368/1000] Train: s_v=5.0e-06, neg_v=2.0e-06, c=9.4e-04, drop_c=2.4e-05 | Val: s_v=4.3e-06, neg_v=6.6e-07, c=6.6e-04, drop_c=1.1e-06
# [Epoch 369/1000] Train: s_v=5.0e-06, neg_v=2.1e-06, c=1.0e-03, drop_c=1.2e-05 | Val: s_v=4.4e-06, neg_v=6.8e-07, c=6.7e-04, drop_c=1.4e-06
# [Epoch 370/1000] Train: s_v=5.0e-06, neg_v=2.4e-06, c=1.1e-03, drop_c=2.9e-05 | Val: s_v=4.3e-06, neg_v=6.1e-07, c=6.8e-04, drop_c=1.7e-06
# [Epoch 371/1000] Train: s_v=5.1e-06, neg_v=2.0e-06, c=9.2e-04, drop_c=1.4e-05 | Val: s_v=4.3e-06, neg_v=6.5e-07, c=6.6e-04, drop_c=1.4e-06
# [Epoch 372/1000] Train: s_v=5.0e-06, neg_v=1.9e-06, c=1.1e-03, drop_c=2.1e-05 | Val: s_v=4.3e-06, neg_v=6.7e-07, c=6.7e-04, drop_c=2.2e-06
# [Epoch 373/1000] Train: s_v=4.9e-06, neg_v=2.1e-06, c=9.4e-04, drop_c=2.2e-05 | Val: s_v=4.3e-06, neg_v=6.4e-07, c=6.7e-04, drop_c=9.4e-07
# [Epoch 374/1000] Train: s_v=5.0e-06, neg_v=2.0e-06, c=1.0e-03, drop_c=3.4e-05 | Val: s_v=4.3e-06, neg_v=7.0e-07, c=6.7e-04, drop_c=1.3e-06
# [Epoch 375/1000] Train: s_v=4.9e-06, neg_v=2.0e-06, c=1.0e-03, drop_c=2.7e-05 | Val: s_v=4.3e-06, neg_v=6.6e-07, c=6.7e-04, drop_c=1.3e-06
# [Epoch 376/1000] Train: s_v=5.0e-06, neg_v=2.2e-06, c=9.9e-04, drop_c=2.2e-05 | Val: s_v=4.3e-06, neg_v=6.6e-07, c=6.7e-04, drop_c=1.5e-06
# [Epoch 377/1000] Train: s_v=5.0e-06, neg_v=2.0e-06, c=9.9e-04, drop_c=1.9e-05 | Val: s_v=4.3e-06, neg_v=7.0e-07, c=6.8e-04, drop_c=1.5e-06
# [Epoch 378/1000] Train: s_v=4.9e-06, neg_v=2.3e-06, c=1.1e-03, drop_c=3.1e-05 | Val: s_v=4.2e-06, neg_v=6.6e-07, c=6.8e-04, drop_c=1.0e-06
# [Epoch 379/1000] Train: s_v=4.8e-06, neg_v=1.9e-06, c=9.8e-04, drop_c=2.2e-05 | Val: s_v=4.2e-06, neg_v=6.2e-07, c=6.8e-04, drop_c=9.4e-07
# [Epoch 380/1000] Train: s_v=4.9e-06, neg_v=2.0e-06, c=9.6e-04, drop_c=1.6e-05 | Val: s_v=4.2e-06, neg_v=6.0e-07, c=6.7e-04, drop_c=1.0e-06
# [Epoch 381/1000] Train: s_v=4.7e-06, neg_v=1.6e-06, c=9.1e-04, drop_c=1.1e-05 | Val: s_v=4.2e-06, neg_v=5.8e-07, c=6.6e-04, drop_c=1.2e-06
# [Epoch 382/1000] Train: s_v=4.9e-06, neg_v=2.3e-06, c=9.5e-04, drop_c=2.4e-05 | Val: s_v=4.2e-06, neg_v=5.8e-07, c=6.5e-04, drop_c=1.1e-06
# [Epoch 383/1000] Train: s_v=4.8e-06, neg_v=2.0e-06, c=9.6e-04, drop_c=1.9e-05 | Val: s_v=4.2e-06, neg_v=6.3e-07, c=6.6e-04, drop_c=1.2e-06
# [Epoch 384/1000] Train: s_v=4.9e-06, neg_v=1.7e-06, c=9.8e-04, drop_c=2.7e-05 | Val: s_v=4.2e-06, neg_v=6.3e-07, c=6.6e-04, drop_c=1.9e-06
# [Epoch 385/1000] Train: s_v=4.9e-06, neg_v=1.8e-06, c=1.1e-03, drop_c=2.6e-05 | Val: s_v=4.2e-06, neg_v=6.5e-07, c=6.6e-04, drop_c=1.5e-06
# [Epoch 386/1000] Train: s_v=4.9e-06, neg_v=2.2e-06, c=9.6e-04, drop_c=2.7e-05 | Val: s_v=4.2e-06, neg_v=6.1e-07, c=6.5e-04, drop_c=1.3e-06
# [Epoch 387/1000] Train: s_v=4.8e-06, neg_v=2.1e-06, c=9.1e-04, drop_c=1.9e-05 | Val: s_v=4.2e-06, neg_v=6.0e-07, c=6.6e-04, drop_c=1.0e-06
# [Epoch 388/1000] Train: s_v=4.9e-06, neg_v=1.9e-06, c=9.9e-04, drop_c=2.8e-05 | Val: s_v=4.2e-06, neg_v=5.9e-07, c=6.5e-04, drop_c=9.8e-07
# [Epoch 389/1000] Train: s_v=4.9e-06, neg_v=2.8e-06, c=9.9e-04, drop_c=2.1e-05 | Val: s_v=4.2e-06, neg_v=5.9e-07, c=6.6e-04, drop_c=1.2e-06
# [Epoch 390/1000] Train: s_v=4.9e-06, neg_v=2.2e-06, c=9.1e-04, drop_c=2.1e-05 | Val: s_v=4.2e-06, neg_v=5.9e-07, c=6.6e-04, drop_c=1.6e-06
# [Epoch 391/1000] Train: s_v=4.9e-06, neg_v=1.9e-06, c=9.9e-04, drop_c=2.3e-05 | Val: s_v=4.2e-06, neg_v=5.6e-07, c=6.5e-04, drop_c=1.7e-06
# [Epoch 392/1000] Train: s_v=4.8e-06, neg_v=1.8e-06, c=1.0e-03, drop_c=1.6e-05 | Val: s_v=4.2e-06, neg_v=5.7e-07, c=6.5e-04, drop_c=1.2e-06
# [Epoch 393/1000] Train: s_v=4.8e-06, neg_v=1.5e-06, c=9.4e-04, drop_c=1.3e-05 | Val: s_v=4.2e-06, neg_v=5.8e-07, c=6.5e-04, drop_c=1.7e-06
# [Epoch 394/1000] Train: s_v=4.9e-06, neg_v=2.2e-06, c=1.0e-03, drop_c=3.0e-05 | Val: s_v=4.2e-06, neg_v=5.8e-07, c=6.5e-04, drop_c=1.4e-06
# [Epoch 395/1000] Train: s_v=4.9e-06, neg_v=1.9e-06, c=8.7e-04, drop_c=3.6e-05 | Val: s_v=4.2e-06, neg_v=5.7e-07, c=6.5e-04, drop_c=1.3e-06
# [Epoch 396/1000] Train: s_v=4.9e-06, neg_v=2.2e-06, c=1.1e-03, drop_c=3.4e-05 | Val: s_v=4.2e-06, neg_v=6.2e-07, c=6.5e-04, drop_c=1.5e-06
# [Epoch 397/1000] Train: s_v=4.9e-06, neg_v=1.9e-06, c=9.1e-04, drop_c=2.9e-05 | Val: s_v=4.2e-06, neg_v=6.2e-07, c=6.6e-04, drop_c=1.2e-06
# [Epoch 398/1000] Train: s_v=4.8e-06, neg_v=1.6e-06, c=9.6e-04, drop_c=2.2e-05 | Val: s_v=4.2e-06, neg_v=6.2e-07, c=6.5e-04, drop_c=1.0e-06
# [Epoch 399/1000] Train: s_v=4.8e-06, neg_v=3.0e-06, c=1.1e-03, drop_c=3.0e-05 | Val: s_v=4.2e-06, neg_v=6.4e-07, c=6.5e-04, drop_c=1.1e-06
# [Epoch 400/1000] Train: s_v=4.8e-06, neg_v=1.9e-06, c=1.0e-03, drop_c=1.3e-05 | Val: s_v=4.2e-06, neg_v=6.6e-07, c=6.5e-04, drop_c=1.4e-06
# [Epoch 401/1000] Train: s_v=4.8e-06, neg_v=2.4e-06, c=9.9e-04, drop_c=2.8e-05 | Val: s_v=4.2e-06, neg_v=6.8e-07, c=6.5e-04, drop_c=1.4e-06
# [Epoch 402/1000] Train: s_v=4.8e-06, neg_v=2.2e-06, c=1.1e-03, drop_c=3.4e-05 | Val: s_v=4.1e-06, neg_v=6.5e-07, c=6.5e-04, drop_c=1.2e-06
# [Epoch 403/1000] Train: s_v=4.8e-06, neg_v=2.1e-06, c=9.5e-04, drop_c=1.7e-05 | Val: s_v=4.2e-06, neg_v=6.7e-07, c=6.5e-04, drop_c=1.5e-06
# [Epoch 404/1000] Train: s_v=4.7e-06, neg_v=1.6e-06, c=9.2e-04, drop_c=1.6e-05 | Val: s_v=4.1e-06, neg_v=6.3e-07, c=6.5e-04, drop_c=1.9e-06
# [Epoch 405/1000] Train: s_v=4.8e-06, neg_v=2.0e-06, c=8.9e-04, drop_c=2.8e-05 | Val: s_v=4.1e-06, neg_v=5.8e-07, c=6.4e-04, drop_c=1.4e-06
# [Epoch 406/1000] Train: s_v=4.8e-06, neg_v=1.9e-06, c=9.4e-04, drop_c=3.1e-05 | Val: s_v=4.1e-06, neg_v=5.5e-07, c=6.5e-04, drop_c=1.3e-06
# [Epoch 407/1000] Train: s_v=4.7e-06, neg_v=2.2e-06, c=9.2e-04, drop_c=1.7e-05 | Val: s_v=4.1e-06, neg_v=5.7e-07, c=6.5e-04, drop_c=1.4e-06
# [Epoch 408/1000] Train: s_v=4.8e-06, neg_v=1.9e-06, c=1.1e-03, drop_c=1.8e-05 | Val: s_v=4.1e-06, neg_v=6.1e-07, c=6.7e-04, drop_c=2.2e-06
# [Epoch 409/1000] Train: s_v=4.7e-06, neg_v=1.9e-06, c=9.6e-04, drop_c=1.5e-05 | Val: s_v=4.1e-06, neg_v=6.2e-07, c=6.5e-04, drop_c=1.4e-06
# [Epoch 410/1000] Train: s_v=4.7e-06, neg_v=1.8e-06, c=9.9e-04, drop_c=3.3e-05 | Val: s_v=4.1e-06, neg_v=6.3e-07, c=6.5e-04, drop_c=1.4e-06
# [Epoch 411/1000] Train: s_v=4.7e-06, neg_v=2.3e-06, c=1.0e-03, drop_c=2.2e-05 | Val: s_v=4.1e-06, neg_v=6.3e-07, c=6.5e-04, drop_c=1.4e-06
# [Epoch 412/1000] Train: s_v=4.8e-06, neg_v=2.0e-06, c=9.9e-04, drop_c=2.1e-05 | Val: s_v=4.1e-06, neg_v=6.4e-07, c=6.6e-04, drop_c=1.3e-06
# [Epoch 413/1000] Train: s_v=4.7e-06, neg_v=2.0e-06, c=8.5e-04, drop_c=2.1e-05 | Val: s_v=4.1e-06, neg_v=6.1e-07, c=6.5e-04, drop_c=1.2e-06
# [Epoch 414/1000] Train: s_v=4.8e-06, neg_v=2.0e-06, c=9.2e-04, drop_c=2.8e-05 | Val: s_v=4.1e-06, neg_v=6.2e-07, c=6.5e-04, drop_c=1.3e-06
# [Epoch 415/1000] Train: s_v=4.8e-06, neg_v=2.2e-06, c=9.0e-04, drop_c=1.1e-05 | Val: s_v=4.1e-06, neg_v=5.7e-07, c=6.5e-04, drop_c=1.3e-06
# [Epoch 416/1000] Train: s_v=4.7e-06, neg_v=2.0e-06, c=9.0e-04, drop_c=2.1e-05 | Val: s_v=4.1e-06, neg_v=5.8e-07, c=6.5e-04, drop_c=1.3e-06
# [Epoch 417/1000] Train: s_v=4.8e-06, neg_v=2.0e-06, c=1.0e-03, drop_c=1.7e-05 | Val: s_v=4.1e-06, neg_v=5.6e-07, c=6.5e-04, drop_c=8.7e-07
# [Epoch 418/1000] Train: s_v=4.8e-06, neg_v=2.1e-06, c=8.8e-04, drop_c=2.6e-05 | Val: s_v=4.1e-06, neg_v=5.8e-07, c=6.5e-04, drop_c=9.8e-07
# [Epoch 419/1000] Train: s_v=4.7e-06, neg_v=1.7e-06, c=9.6e-04, drop_c=2.3e-05 | Val: s_v=4.1e-06, neg_v=5.8e-07, c=6.5e-04, drop_c=8.4e-07
# [Epoch 420/1000] Train: s_v=4.8e-06, neg_v=2.8e-06, c=1.1e-03, drop_c=2.3e-05 | Val: s_v=4.1e-06, neg_v=5.7e-07, c=6.6e-04, drop_c=9.8e-07
# [Epoch 421/1000] Train: s_v=4.7e-06, neg_v=1.7e-06, c=9.4e-04, drop_c=1.5e-05 | Val: s_v=4.1e-06, neg_v=5.8e-07, c=6.5e-04, drop_c=9.4e-07

# %%
import json
import numpy as np
import tensorflow as tf
import model
import utils  # if you need r2_growth_curve later
import model  # if you need r2_growth_curve later
import os

metabolite_ids = [
'glc__D_e', 'xyl__D_e', 'succ_e', 'ala__L_e', 'arg__L_e', 'asn__L_e', 'asp__L_e',
'cys__L_e', 'glu__L_e', 'gln__L_e', 'gly_e', 'his__L_e', 'ile__L_e', 'leu__L_e',
'lys__L_e', 'met__L_e', 'phe__L_e', 'pro__L_e', 'ser__L_e', 'thr__L_e', 'trp__L_e',
'tyr__L_e', 'val__L_e', 'ade_e', 'gua_e', 'csn_e', 'ura_e', 'thymd_e', 'BIOMASS'
]
# -------------------------------------------------------------------
# 1) Paths to the two models you want to compare
# -------------------------------------------------------------------
# Example: old = July model, new = current retrain
old_base = "./model_july31/M28_OD_20_forecast_0"   # <--- adjust to your old files
new_base = "./model/M28_OD_20_forecast_0"        # <--- adjust to your new files

old_config_path = old_base + ".config.json"
new_config_path = new_base + ".config.json"

old_weights_path = old_base + ".weights.h5"
new_weights_path = new_base + ".weights.h5"

print("Old config exists :", os.path.exists(old_config_path))
print("Old weights exist:", os.path.exists(old_weights_path))
print("New config exists :", os.path.exists(new_config_path))
print("New weights exist:", os.path.exists(new_weights_path))

# -------------------------------------------------------------------
# 2) Load and diff configs
# -------------------------------------------------------------------
def load_config(path):
    with open(path, "r") as f:
        return json.load(f)

old_cfg = load_config(old_config_path)
new_cfg = load_config(new_config_path)

print("\n=== CONFIG DIFF ===")
all_keys = sorted(set(old_cfg.keys()) | set(new_cfg.keys()))
for k in all_keys:
    v_old = old_cfg.get(k, "<MISSING>")
    v_new = new_cfg.get(k, "<MISSING>")
    if v_old != v_new:
        print(f"{k}:")
        print(f"  old = {v_old}")
        print(f"  new = {v_new}")
print("=== END CONFIG DIFF ===\n")

# -------------------------------------------------------------------
# 3) Load models from disk using your MetabolicModel.load_model
# -------------------------------------------------------------------
print("Loading old model...")
new_model = model.MetabolicModel.load_model(model_name=new_base, metabolite_ids=metabolite_ids, verbose=False)
old_model = model.MetabolicModel.load_model(model_name=old_base, metabolite_ids=metabolite_ids, verbose=False)

print("\nOld model params:", old_model.count_params())
print("New model params:", new_model.count_params())

# -------------------------------------------------------------------
# 4) Compare weights (only if architectures match)
# -------------------------------------------------------------------
old_weights = old_model.get_weights()
new_weights = new_model.get_weights()

print("\n=== WEIGHT COMPARISON ===")
print("Number of weight arrays: old =", len(old_weights), " new =", len(new_weights))
if len(old_weights) != len(new_weights):
    print("WARNING: different number of weight tensors → architectures changed.")
else:
    for i, (ow, nw) in enumerate(zip(old_weights, new_weights)):
        if ow.shape != nw.shape:
            print(f"Layer {i}: shape mismatch old {ow.shape} vs new {nw.shape}")
            continue
        diff = np.linalg.norm(ow - nw)
        n_old = np.linalg.norm(ow)
        n_new = np.linalg.norm(nw)
        print(f"Layer {i}: ||old-new|| = {diff:.3e}, ||old|| = {n_old:.3e}, ||new|| = {n_new:.3e}")
print("=== END WEIGHT COMPARISON ===\n")

# -------------------------------------------------------------------
# 5) Compare predictions on the SAME validation data
# -------------------------------------------------------------------
val_array_path = "./model_july31/M28_OD_20_forecast_val_array.txt"  # adjust if name differs

val_array = np.loadtxt(val_array_path, dtype=float)
print("val_array shape:", val_array.shape)

# Old model predictions
old_pred, old_ref = model.predict_on_val_data(old_model, val_array, verbose=False)
old_pred = np.asarray(old_pred)
old_ref  = np.asarray(old_ref)

# New model predictions
new_pred, new_ref = model.predict_on_val_data(new_model, val_array, verbose=False)
new_pred = np.asarray(new_pred)
new_ref  = np.asarray(new_ref)

print("\nCheck that references match (they should):",
      np.allclose(old_ref, new_ref, equal_nan=True))

# Example: growth-curve R² (like you already do)
OD = True
R2_old = utils.r2_growth_curve(np.expand_dims(old_pred, 0),
                               np.expand_dims(old_ref, 0),
                               OD=OD)
R2_new = utils.r2_growth_curve(np.expand_dims(new_pred, 0),
                               np.expand_dims(new_ref, 0),
                               OD=OD)

print(f"\nOld model: mean R2 = {np.mean(R2_old):.3f}")
print(f"New model: mean R2 = {np.mean(R2_new):.3f}")

# Also inspect numeric difference in predictions
diff_pred = new_pred - old_pred
print("\nPrediction difference stats (new - old):")
print("  abs mean:", np.nanmean(np.abs(diff_pred)))
print("  abs max :", np.nanmax(np.abs(diff_pred)))
# Out:
# Old config exists : True
# Old weights exist: True
# New config exists : True
# New weights exist: True
#
# === CONFIG DIFF ===
# UB_in:
#   old = <MISSING>
#   new = 0.0
# UB_out:
#   old = <MISSING>
#   new = 0.0
# metabolite_ids:
#   old = <MISSING>
#   new = ['glc__D_e', 'xyl__D_e', 'succ_e', 'ala__L_e', 'arg__L_e', 'asn__L_e', 'asp__L_e', 'cys__L_e', 'glu__L_e', 'gln__L_e', 'gly_e', 'his__L_e', 'ile__L_e', 'leu__L_e', 'lys__L_e', 'met__L_e', 'phe__L_e', 'pro__L_e', 'ser__L_e', 'thr__L_e', 'trp__L_e', 'tyr__L_e', 'val__L_e', 'ade_e', 'gua_e', 'csn_e', 'ura_e', 'thymd_e', 'BIOMASS']
# times:
#   old = [0.322222222, 1.5678362571578943, 2.81345029231579, 4.059064327473684, 5.304678362631578, 6.550292397789472, 7.795906432947367, 9.041520468105263, 10.287134503263156, 11.532748538421052, 12.778362573578946, 14.023976608736842, 15.269590643894736, 16.51520467905263, 17.760818714210526, 19.00643274936842, 20.25204678452631, 21.497660819684207, 22.743274854842102, 23.98888889]
#   new = [0.3222222328186035, 1.5678362846374512, 2.813450336456299, 4.0590643882751465, 5.304678440093994, 6.550292491912842, 7.7959065437316895, 9.041520118713379, 10.287134170532227, 11.532748222351074, 12.778362274169922, 14.02397632598877, 15.269590377807617, 16.51520538330078, 17.760818481445312, 19.006433486938477, 20.252046585083008, 21.497661590576172, 22.743274688720703, 23.988889694213867]
# === END CONFIG DIFF ===
#
# Loading old model...
#
# Old model params: 1861284
# New model params: 1861284
#
# === WEIGHT COMPARISON ===
# Number of weight arrays: old = 8  new = 8
# Layer 0: ||old-new|| = 9.746e+00, ||old|| = 6.461e+00, ||new|| = 7.083e+00
# Layer 1: ||old-new|| = 9.104e-01, ||old|| = 2.475e-01, ||new|| = 8.405e-01
# Layer 2: ||old-new|| = 3.052e+00, ||old|| = 1.899e+00, ||new|| = 2.181e+00
# Layer 3: ||old-new|| = 1.159e-01, ||old|| = 2.429e-02, ||new|| = 1.312e-01
# Layer 4: ||old-new|| = 1.057e+01, ||old|| = 7.510e+00, ||new|| = 7.477e+00
# Layer 5: ||old-new|| = 5.715e-01, ||old|| = 6.359e-01, ||new|| = 5.216e-01
# Layer 6: ||old-new|| = 3.792e+01, ||old|| = 3.288e+01, ||new|| = 3.273e+01
# Layer 7: ||old-new|| = 8.003e-01, ||old|| = 2.129e+00, ||new|| = 1.647e+00
# === END WEIGHT COMPARISON ===
